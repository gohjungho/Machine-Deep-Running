# %%
import os
import pickle
# 수학 관련 라이브러리
import numpy as np
import math
# pytorch 관련 라이브러리
import torch
import torch.nn as nn 
import torch.nn.functional as F 

import pandas as pd
import nltk
import tqdm
from torch.utils import data # dataset 관련된 utility 를 사용하려는 용도
from random import choice, randrange # random
from itertools import zip_longest 
import json 
import random
import pdb


nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# 파일 올리기
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-226dd217-fae0-4dc3-b4b6-4817900beb5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-226dd217-fae0-4dc3-b4b6-4817900beb5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_files.zip to data_files.zip

# %%
# !unzip data_files.zip
# Out:
# Archive:  data_files.zip
#   inflating: english_id2word.pkl
#   inflating: english_vocab.pkl
#   inflating: english_word2id.pkl
#    creating: korean_data/
#   inflating: korean_data/test_english.csv
#   inflating: korean_data/test_korean.csv
#   inflating: korean_data/train.csv
#   inflating: korean_id2word.pkl
#   inflating: korean_vocab.pkl
#   inflating: korean_word2id.pkl
#   inflating: train_english.pkl
#   inflating: train_korean.pkl

# %%
def split_last(x, shape):
    "split the last dimension to given shape"
    shape = list(shape)
    assert shape.count(-1) <= 1
    if -1 in shape:
        shape[shape.index(-1)] = int(x.size(-1) / -np.prod(shape))
    return x.view(*x.size()[:-1], *shape)

def merge_last(x, n_dims):
    "merge the last n_dims to a dimension"
    s = x.size()
    assert n_dims > 1 and n_dims < len(s)
    return x.view(*s[:-n_dims], -1)

# %% [markdown]
# # Activation function

# %%
def gelu(x):
    return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))

# %% [markdown]
# # Layer normalization

# %%
class LayerNorm(nn.Module):
    def __init__(self, cfg, variance_epsilon=1e-12):
        super().__init__()
        self.gamma = nn.Parameter(torch.ones(cfg.dim))
        self.beta  = nn.Parameter(torch.zeros(cfg.dim))
        self.variance_epsilon = variance_epsilon

    def forward(self, x):
        # get mean, variance
        u = x.mean(-1, keepdim=True) # sequence 방향 mean
        s = (x - u).pow(2).mean(-1, keepdim=True) # sequence 방향 variance
        
        # normalize
        x = (x - u) / torch.sqrt(s + self.variance_epsilon) # (x - mean)/std 
        
        return self.gamma * x + self.beta # gamma, beta를 이용해 mean, std 조정

# %% [markdown]
# # Embedding

# %%
def get_sinusoid_encoding_table(n_position, d_model):
    def cal_angle(position, hid_idx):
        return position / np.power(10000, 2 * (hid_idx // 2) / d_model)
    def get_posi_angle_vec(position):
        return [cal_angle(position, hid_j) for hid_j in range(d_model)]

    sinusoid_table = np.array([get_posi_angle_vec(pos_i) for pos_i in range(n_position)])
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])  # dim 2i
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])  # dim 2i+1
    return torch.FloatTensor(sinusoid_table)


class Embeddings(nn.Module):
    "The embedding module from word, position and token_type embeddings."
    def __init__(self, cfg, vocab_size):
        super().__init__()
        
        self.tok_embed = nn.Embedding(vocab_size, cfg.dim) # token embedding
        self.pos_embed = nn.Embedding.from_pretrained(get_sinusoid_encoding_table(512, cfg.dim),freeze=True) # position embedding

        self.norm = LayerNorm(cfg)
        self.drop = nn.Dropout(cfg.p_drop_hidden)

    def forward(self, x):
        seq_len = x.size(1)
        pos = torch.arange(seq_len, dtype=torch.long, device=x.device) # 0,1,2,3,4,5, ..., seq_len-1
        pos = pos.unsqueeze(0).expand_as(x) # (S,) -> (B, S)

        e = self.tok_embed(x) + self.pos_embed(pos)
        return self.drop(self.norm(e))

# %% [markdown]
# #  Transformer encoder

# %%
class Attention(nn.Module):
    #Scaled Dot Product Attention
    
    def forward(self, query, key, value, mask=None, dropout=None):
        scores = torch.matmul(query, key.transpose(-2, -1)) / math.sqrt(query.size(-1)) # scale
        
        
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)

        p_attn = F.softmax(scores, dim=-1)

        if dropout is not None:
            p_attn = dropout(p_attn)

        return torch.matmul(p_attn, value), p_attn

# %%
class MultiHeadAttention(nn.Module):
    """ Multi-Headed Dot Product Attention """
    def __init__(self, cfg):
        super().__init__()
        self.proj_q = nn.Linear(cfg.dim, cfg.dim)
        self.proj_k = nn.Linear(cfg.dim, cfg.dim)
        self.proj_v = nn.Linear(cfg.dim, cfg.dim)
        self.drop = nn.Dropout(cfg.p_drop_attn)
        self.scores = None # for visualization
        self.n_heads = cfg.n_heads

    def forward(self, x, mask, x_q=None):
        """
        x, q(query), k(key), v(value) : (B(batch_size), S(seq_len), D(dim))
        mask : (B(batch_size) x S(seq_len))
        * split D(dim) into (H(n_heads), W(width of head)) ; D = H * W
        """
        
        # (B, S, D) -proj-> (B, S, D) -split-> (B, S, H, W) -trans-> (B, H, S, W)
        if x_q is None:
            q, k, v = self.proj_q(x), self.proj_k(x), self.proj_v(x)
        else:
            q, k, v = self.proj_q(x_q), self.proj_k(x), self.proj_v(x)
        q, k, v = (split_last(x, (self.n_heads, -1)).transpose(1, 2)
                   for x in [q, k, v])
        # (B, H, S, W) @ (B, H, W, S) -> (B, H, S, S) -softmax-> (B, H, S, S)
        scores = torch.matmul(q, k.transpose(-2, -1)) / np.sqrt(k.size(-1)) # @ == torch.matmul (dot product)
        if mask is not None:
            mask = mask.unsqueeze(1).repeat(1, self.n_heads, 1, 1)
            scores = scores.masked_fill_(mask, -1e9)
        scores = self.drop(F.softmax(scores, dim=-1))
        # (B, H, S, S) @ (B, H, S, W) -> (B, H, S, W) -trans-> (B, S, H, W)
        h = torch.matmul(scores, v).transpose(1,2).contiguous()
        # -merge-> (B, S, D)
        h = merge_last(h, 2)
        self.scores = scores
        return h

# %% [markdown]
# # Base feedforward network

# %%
class PositionWiseFeedForward(nn.Module):
    """ FeedForward Neural Networks for each position """
    def __init__(self, cfg):
        super().__init__()
        self.fc1 = nn.Linear(cfg.dim, cfg.dim_ff)
        self.fc2 = nn.Linear(cfg.dim_ff, cfg.dim)

    def forward(self, x):
        # (B, S, D) -> (B, S, D_ff) -> (B, S, D)
        return self.fc2(gelu(self.fc1(x)))

# %% [markdown]
# # Transformer

# %%
class Encoder_Block(nn.Module):
    """ Transformer Block """
    def __init__(self, cfg):
        super().__init__()
        self.attn = MultiHeadAttention(cfg)
        self.proj = nn.Linear(cfg.dim, cfg.dim)
        self.norm1 = LayerNorm(cfg)
        self.pwff = PositionWiseFeedForward(cfg)
        self.norm2 = LayerNorm(cfg)
        self.drop = nn.Dropout(cfg.p_drop_hidden)

    def forward(self, x, mask):
        h = self.attn(x, mask)
        h = self.norm1(x + self.drop(self.proj(h)))
        h = self.norm2(h + self.drop(self.pwff(h)))
        return h
    
def get_attn_pad_mask(seq_q, seq_k):
    batch_size, len_q = seq_q.size()
    batch_size, len_k = seq_k.size()
    # eq(zero) is PAD token
    pad_attn_mask = seq_k.data.eq(0).unsqueeze(1)  # batch_size x 1 x len_k(=len_q), one is masking
    return pad_attn_mask.expand(batch_size, len_q, len_k)  # batch_size x len_q x len_k
    
def get_attn_subsequent_mask(seq):
    attn_shape = [seq.size(0), seq.size(1), seq.size(1)]
    subsequent_mask = np.triu(np.ones(attn_shape), k=1)
    subsequent_mask = torch.tensor(subsequent_mask, device=seq.device).byte()
    return subsequent_mask
    
    
class Decoder_Block(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.self_attention = MultiHeadAttention(cfg)
        self.encoder_attention = MultiHeadAttention(cfg)
        
        self.norm1 = LayerNorm(cfg)
        self.proj1 = nn.Linear(cfg.dim, cfg.dim)
        self.norm2 = LayerNorm(cfg)
        self.proj2 = nn.Linear(cfg.dim, cfg.dim)
        
        self.pwff = PositionWiseFeedForward(cfg)
        self.norm3 = LayerNorm(cfg)
        
        self.drop = nn.Dropout(cfg.p_drop_hidden)
        
    def forward(self,x , enc_outputs, dec_self_attn_mask, dec_enc_attn_mask):
        
        # self-attention -> add&norm
        h = self.self_attention(x, dec_self_attn_mask)
        h = self.norm1(x + self.drop(self.proj1(h)))
        
        # encoder attention -> add&norm
        h2 = self.encoder_attention(enc_outputs, dec_enc_attn_mask, x_q=h)
        h = self.norm2(h + self.drop(self.proj2(h2))) 
        
        # feedforward network
        h = self.norm3(h + self.drop(self.pwff(h)))
        
        return h

class Transformer(nn.Module):
    """ Transformer with Self-Attentive Blocks"""
    def __init__(self, cfg):
        super().__init__()
        #====================encoder===========================
        self.encoder_embed = Embeddings(cfg, len(korean_vocab))
        self.encoder_blocks = nn.ModuleList([Encoder_Block(cfg) for _ in range(cfg.n_layers)])

        #====================decoder============================
        self.decoder_embed = Embeddings(cfg, len(english_vocab))
        self.decoder_blocks = nn.ModuleList([Decoder_Block(cfg) for _ in range(cfg.n_layers)])
        
        #=========================================================
        self.projection = nn.Linear(cfg.dim, len(english_vocab))
        
        
    def forward(self, enc_inputs, dec_inputs):
        #============encoder============
        h = self.encoder_embed(enc_inputs)
        enc_self_attn_mask = get_attn_pad_mask(enc_inputs, enc_inputs)
        for block in self.encoder_blocks:
            h = block(h, enc_self_attn_mask)
            
        enc_outputs = h
        
        
        #============decoder============
        
        # self attention mask
        dec_self_attn_pad_mask = get_attn_pad_mask(dec_inputs, dec_inputs).float()
        dec_self_attn_subsequent_mask = get_attn_subsequent_mask(dec_inputs).float()
        dec_self_attn_mask = torch.gt((dec_self_attn_pad_mask + dec_self_attn_subsequent_mask), 0)

        # encoder attention mask
        dec_enc_attn_mask = get_attn_pad_mask(dec_inputs, enc_inputs)
        
        
        # embedding
        h = self.decoder_embed(dec_inputs)
        
        
        for block in self.decoder_blocks:
            h = block(h, enc_outputs, dec_self_attn_mask, dec_enc_attn_mask)
        #============projection==========
        
        out = self.projection(h)
        
        return out
    
    def greedy_decoding(self, enc_inputs, start_token_index = 1, end_token_index = 2, generation_max_len=128):
        
        with torch.no_grad():
            batch_size, max_length = enc_inputs.size()
            generation_end_flag = [0 for i in range(batch_size)]
            predicted_sentences = []
            #=================encoding=============
            h = self.encoder_embed(enc_inputs)
            enc_self_attn_mask = get_attn_pad_mask(enc_inputs, enc_inputs)
            for block in self.encoder_blocks:
                h = block(h, enc_self_attn_mask)    
            enc_outputs = h

            #================ greedy decoding ==================
            # dec_inputs : (batch size, 1) # <s>
            dec_inputs = torch.ones(batch_size, 1, device=enc_inputs.device) * start_token_index
            dec_inputs = dec_inputs.long()

            for i in range(generation_max_len):

                #====================== decoder =======================
                # self attention mask
                dec_self_attn_pad_mask = None
                dec_self_attn_subsequent_mask = None
                dec_self_attn_mask = None

                # encoder attention mask
                dec_enc_attn_mask = None


                # embedding
                h = self.decoder_embed(dec_inputs)


                for block in self.decoder_blocks:
                    h = block(h, enc_outputs, dec_self_attn_mask, dec_enc_attn_mask)


                out = self.projection(h[:,-1,:]) # [B, S, D] # -1는 마지막 새 단어를 만들어야하므로 
                pred = out.argmax(-1) # argmax: 가장 확률이 높은 값을 반환 # max는 값, argmax는 인덱스

#                 print(out.size(), pred)

                dec_inputs = torch.cat((dec_inputs, pred.unsqueeze(1)),dim=1)
                # (B, 1) -> (B, 2) -> (B, 3) -> ... -> (B, max_length)

    #             print(dec_inputs)

                predicted_sentences.append(pred)
                for j, boolean in enumerate(pred==end_token_index): # <s>
                    if boolean == True:
                        generation_end_flag[j] = 1
                if sum(generation_end_flag) == batch_size:
                    break

        return torch.stack(predicted_sentences, dim=1)

# %%
# 한 -> 영
data_ = pd.read_csv("./korean_data/train.csv")
korean_data = data_["Korean"].values
english_data = data_["English"].values

# %%
nltk.tokenize.word_tokenize(korean_data[100])
# nltk / spacy 차이는 구글에게 물어보기
# Out:
# ['그것을', '막기', '위해', ',', '많은', '과학자는', '친환경적인', '사용', '방법을', '연구했어요', '.']

# %%
def build_dict(seqs):
    num_skip_sent = 0
    word_count = 4
    vocab = ["<pad>","<s>","</s>","<unk>"]
    word2id = {"<pad>": 0, "<s>": 1, "</s>": 2, "<unk>": 3}
    id2word = {0: "<pad>", 1: "<s>", 2: "</s>", 3: "<unk>"}
    print("Building vocab and dict..")
    for line in seqs:
        words = line.strip().split(' ') # tokenized by space 
        for word in words:
            if word not in vocab:
                word_count += 1 # increment word_count
                vocab.append(word) # append new unique word
                index = word_count - 1 # word index (consider index 0)
                word2id[word] = index # word to index
                id2word[index] = word # index to word
    
    print("Number of unique words: %d" % len(vocab))
    print("Finised building vocab and dict!")

    return vocab, word2id, id2word

# %%
if os.path.isfile("./korean_vocab.pkl"):
    with open("./train_korean.pkl", "rb") as f:
        korean_data_token_ = pickle.load(f)
    with open("./train_english.pkl", "rb") as f:
        english_data_token_ = pickle.load(f)    
    
    with open("./korean_vocab.pkl", "rb") as f:
        korean_vocab = pickle.load(f)
    with open("./korean_word2id.pkl", "rb") as f:
        korean_word2id = pickle.load(f)
    with open("./korean_id2word.pkl", "rb") as f:
        korean_id2word = pickle.load(f)
    with open("./english_vocab.pkl", "rb") as f:
        english_vocab = pickle.load(f)
    with open("./english_word2id.pkl", "rb") as f:
        english_word2id = pickle.load(f)
    with open("./english_id2word.pkl", "rb") as f:
        english_id2word = pickle.load(f)

else:
    korean_data_token = []
    for sent in korean_data:
        korean_data_token.append([token for token in nltk.tokenize.word_tokenize(sent)])

    english_data_token = []
    for sent in english_data:
        english_data_token.append([token for token in nltk.tokenize.word_tokenize(sent)])

    korean_data_token_ = [' '.join(token) for token in korean_data_token]
    english_data_token_ = [' '.join(token) for token in english_data_token]    
    
    korean_vocab, korean_word2id, korean_id2word = build_dict(korean_data_token_)
    english_vocab, english_word2id, english_id2word = build_dict(english_data_token_)
    
    pickle.dump(korean_data_token_, open("./train_korean.pkl", "wb" ))
    pickle.dump(english_data_token_, open("./train_english.pkl", "wb" ))    
    
    pickle.dump(korean_vocab, open("./korean_vocab.pkl", "wb" ))
    pickle.dump(korean_word2id, open("./korean_word2id.pkl", "wb" ))
    pickle.dump(korean_id2word, open("./korean_id2word.pkl", "wb" ))

    pickle.dump(english_vocab, open("./english_vocab.pkl", "wb" ))
    pickle.dump(english_word2id, open("./english_word2id.pkl", "wb" ))
    pickle.dump(english_id2word, open("./english_id2word.pkl", "wb" ))

# %%
korean_vocab
# Out:
# ['<pad>',
#  '<s>',
#  '</s>',
#  '<unk>',
#  '그들은',
#  '현실에',
#  '대해',
#  '지나치게',
#  '냉소적인',
#  '태도를',
#  '지니고',
#  '있었습니다',
#  '.',
#  '경기장',
#  '근처의',
#  '공영',
#  '주차장을',
#  '이용하시면',
#  '됩니다',
#  '티켓은',
#  '앞면에',
#  '명시된',
#  '경기장에서만',
#  '유효합니다',
#  '매장에',
#  '좋은',
#  '리뷰를',
#  '올려주신',
#  '고객님께',
#  '추첨을',
#  '통해',
#  '1만원권',
#  '쿠폰을',
#  '지급해드립니다',
#  '어제',
#  '백화점에',
#  '물건',
#  '사러',
#  '갔다',
#  '왔어요',
#  '나는',
#  '지금',
#  '전혀',
#  '괜찮지',
#  '않아서',
#  '좀',
#  '조용히',
#  '혼자',
#  '있고',
#  '싶어요',
#  '우선',
#  '애쉬번햄에서',
#  '하는',
#  '일들을',
#  '익히고',
#  '최선을',
#  '다하고',
#  '싶습니다',
#  '당신은',
#  '트럭을',
#  '운전할',
#  '수',
#  '있습니까',
#  '?',
#  '저는',
#  '프로그래머',
#  '이정수입니다',
#  '불량',
#  '학생들을',
#  '쉽게',
#  '지도할',
#  '있습니다',
#  '자세가',
#  '바르게',
#  '되어',
#  '어깨와',
#  '허리',
#  '통증이',
#  '완화됩니다',
#  '몇',
#  '가지',
#  '질문이',
#  '있어서',
#  '메일을',
#  '드립니다',
#  '너는',
#  '그동안',
#  '나한테',
#  '연락하지',
#  '않았잖아',
#  '우리',
#  '아기가',
#  '원래',
#  '열이',
#  '많은',
#  '체질이라',
#  '여름에',
#  '피부트러블이',
#  '것',
#  '같아요',
#  '그렇게',
#  '생각한다면',
#  '나에게도',
#  '아주',
#  '바쁘고',
#  '힘든',
#  '하루였어',
#  '위의',
#  '문장',
#  '유형은',
#  '일찍',
#  '만나서',
#  '수영을',
#  '즐길',
#  '있음을',
#  '의미합니다',
#  '그들에게',
#  '부산에서의',
#  '오픈을',
#  '위한',
#  '큰',
#  '에너지를',
#  '받았습니다',
#  '내',
#  '친구는',
#  '춤을',
#  '잘',
#  '춥니다',
#  '집에서',
#  '여기까지',
#  '운전해서',
#  '온',
#  '사람',
#  '있나요',
#  '주말에도',
#  '열심히',
#  '공부하는군요',
#  '언제나',
#  '아버지와',
#  '함께라면',
#  '신기하고',
#  '재밌는',
#  '일들이',
#  '많았어요',
#  '이건',
#  '충치가',
#  '사랑하는',
#  '사탕이야',
#  '추석에',
#  '가족들과',
#  '음식도',
#  '만들고',
#  '사촌',
#  '동생들과',
#  '놀아줬습니다',
#  '내가',
#  '예약한',
#  '숙소를',
#  '사용할',
#  '없다고',
#  '나오는데',
#  ',',
#  '문제가',
#  '없나요',
#  '10학번인데',
#  '2학기에',
#  '재입학해서',
#  '지금이',
#  '첫',
#  '수업이에요',
#  '업데이트된',
#  '스케줄을',
#  '저에게',
#  '알려주세요',
#  '비행이',
#  '지연된',
#  '것은',
#  '제',
#  '탓이',
#  '아니라',
#  '날씨',
#  '탓이예요',
#  '켄이',
#  '와서',
#  '이',
#  '문제를',
#  '해결할',
#  '거예요',
#  '상황에서',
#  '가장',
#  '실용적인',
#  '접근',
#  '방식은',
#  '어떤',
#  '것인가요',
#  '당신을',
#  '많이',
#  '좋아했어요',
#  '더는',
#  '사진',
#  '똑바로',
#  '찍으려고',
#  '노력하지',
#  '마',
#  '오늘은',
#  '약속이',
#  '없어서',
#  '집에',
#  '있어요',
#  '포르투갈의',
#  '민요이자',
#  '대중가요인',
#  '파두에',
#  '대해서',
#  '소개하고',
#  '당신이',
#  '가족과',
#  '즐겁게',
#  '지내길',
#  '원해요',
#  '문의하신',
#  '디젤',
#  '트럭',
#  '솔루션은',
#  '저희가',
#  '개발한',
#  'IoT',
#  'Gateway',
#  '단말기를',
#  '적용하면',
#  '되겠습니다',
#  '6개월',
#  '전에',
#  '영국에',
#  '다녀',
#  '왔습니다',
#  '한국에서',
#  '공부를',
#  '하려는거야',
#  '마스크팩',
#  '사용',
#  '후',
#  '눈가',
#  '및',
#  '얼굴',
#  '전체에',
#  '부드럽게',
#  '펴',
#  '바른',
#  '뒤',
#  '가볍게',
#  '두드리며',
#  '흡수시켜줍니다',
#  '지난',
#  '주',
#  '두바이에서',
#  '열린',
#  '전시회에서',
#  '부쓰를',
#  '방문해줘서',
#  '고맙습니다',
#  '거품과',
#  '함께',
#  '노폐물이',
#  '씻겨',
#  '사라지는',
#  '것을',
#  '느껴보세요',
#  '두',
#  '번째',
#  '사진은',
#  '며칠',
#  '학교',
#  '옥상에서',
#  '찍은',
#  '사진입니다',
#  '우리의',
#  '소극적인',
#  '부분이',
#  '사라지고',
#  '창의성을',
#  '키울',
#  '있어',
#  '그',
#  '대학생은',
#  '지적이라기보다는',
#  '영리한',
#  '편이에요',
#  '서해',
#  '해군기지의',
#  '재킷',
#  '식',
#  '구조물이에요',
#  '나에게',
#  '시간을',
#  '준다면',
#  '바꿀',
#  '한',
#  '번은',
#  '비행기에서',
#  '하나를',
#  '그렸어요',
#  '제품을',
#  '급히',
#  '사용해야',
#  '해요',
#  '동시에',
#  '세계보건기구는',
#  '의료보장제도',
#  '부문에서',
#  '미국이',
#  '세계',
#  '30위라고',
#  '판단했어요',
#  '여기서부터',
#  '치외법권',
#  '지역이란',
#  '뜻입니다',
#  '가까운',
#  '마켓이',
#  '어디',
#  '있는지',
#  '그것은',
#  '한국의',
#  '대표적인',
#  '전통춤입니다',
#  '저',
#  '차로',
#  '선택하겠어요',
#  '당신께서',
#  '원한다면',
#  '연말에는',
#  '예약을',
#  '미리',
#  '해야',
#  '저녁에도',
#  '수영장을',
#  '이용할',
#  '그러니까',
#  '무슨',
#  '일을',
#  '할지',
#  '알겠어요',
#  '무엇을',
#  '하려고',
#  '하세요',
#  '이번',
#  '주에',
#  '시에',
#  '만날래요',
#  '어쨌든',
#  '너의',
#  '인생이니까',
#  '네가',
#  '잘살아',
#  '보렴',
#  '안감이',
#  '구겨져',
#  '있는',
#  '형태의',
#  '주머니',
#  '모양이에요',
#  '손목은',
#  '끝이',
#  '점점',
#  '가늘어지는',
#  '구조로',
#  '점이',
#  '움직임을',
#  '용이하게',
#  '1km',
#  '더',
#  '가면',
#  '목적지에',
#  '도착합니다',
#  '지하철',
#  '노선들은',
#  '운영되지',
#  '않고',
#  '있었다',
#  '대회의',
#  '취지는',
#  '스마트폰과',
#  '인터넷으로',
#  '뇌를',
#  '잠시도',
#  '쉬지',
#  '못하는',
#  '현대인의',
#  '삶을',
#  '돌아보자는',
#  '입니다',
#  '말한',
#  '적',
#  '없어',
#  '신세계',
#  '백화점에서',
#  '한국',
#  '전통',
#  '식료품을',
#  '구입하고',
#  '렌즈가',
#  '이미',
#  '수리된',
#  '것으로',
#  '알고',
#  '이렇듯',
#  '광고는',
#  '사람들에게',
#  '사실과는',
#  '다른',
#  '믿게',
#  '만듭니다',
#  '커밍아웃하는',
#  '건',
#  '불가능해',
#  '엄마',
#  '도와주면서',
#  '지내고',
#  '마지막',
#  '시험을',
#  '봐서',
#  '서울',
#  '동성',
#  '고등학교에',
#  '꼭',
#  '가고',
#  '싶다',
#  '그건',
#  '그렇고',
#  '남편께서는',
#  '어떻게',
#  '지내세요',
#  '임다봉',
#  '어서',
#  '일어나서',
#  '밥',
#  '차려줘',
#  '여기는',
#  '엄청',
#  '시끄럽고',
#  '주변에는',
#  '아무것도',
#  '없고',
#  '조개구이집들밖에',
#  '없었어',
#  '아마도',
#  '우리는',
#  '만족스럽게',
#  '진행하기',
#  '어려울',
#  '같습니다',
#  '일하는',
#  '시간은',
#  '평균',
#  '9시간',
#  '정도입니다',
#  '폐기할',
#  '때는',
#  '완전히',
#  '배출한',
#  '재활용합니다',
#  '이러한',
#  '인식',
#  '개선이',
#  '중소',
#  '중견',
#  '기업이',
#  '발전할',
#  '기초적인',
#  '단계라고',
#  '생각해요',
#  '축구의',
#  '매력에',
#  '빠지면',
#  '벗어날',
#  '매장',
#  '내에',
#  '신나는',
#  '음악을',
#  '틀어',
#  '고객들이',
#  '쇼핑하는데',
#  '즐거움을',
#  '느끼게',
#  '합니다',
#  '우리가',
#  '마을에',
#  '도착했을',
#  '때',
#  '모든',
#  '은행이',
#  '문을',
#  '닫았어요',
#  '주문을',
#  '취소하겠다고',
#  '메일',
#  '보냈습니다',
#  '문제는',
#  '열쇠를',
#  '차',
#  '안에',
#  '두고',
#  '잠갔다는',
#  '혹시',
#  '테이블',
#  '세팅을',
#  '변경하실',
#  '의향이',
#  '있으신가요',
#  '이메일과',
#  '비번만',
#  '입력',
#  '회원',
#  '가입하면',
#  '즉시',
#  '로그인되고',
#  '메시지를',
#  '보낼',
#  '문화가',
#  '음식에',
#  '관한',
#  '사람들의',
#  '관점에',
#  '영향을',
#  '준다고',
#  '생각하나요',
#  '설명할',
#  '고려해야',
#  '할',
#  '것이',
#  '일제강점기였지만',
#  '그는',
#  '한국인과',
#  '같이',
#  '독립운동을',
#  '하며',
#  '한국을',
#  '모습을',
#  '보였어요',
#  '가족들은',
#  '우리보다',
#  '여행을',
#  '출발합니다',
#  '나',
#  '자신을',
#  '사랑의',
#  '시작이에요',
#  '스타크래프트에서',
#  '테란',
#  '대형',
#  '트럭이',
#  '사람을',
#  '치고',
#  '도망갔습니다',
#  '사람의',
#  '목숨이',
#  '정치적으로',
#  '이용되는',
#  '이성적으로도',
#  '이해가',
#  '될',
#  '없을',
#  '것입니다',
#  '필요한',
#  '자재에',
#  '공급',
#  '업체에',
#  '발주합니다',
#  '분명',
#  '후회하게',
#  '겁니다',
#  '카트',
#  '상품은',
#  '그대로',
#  '현재',
#  '상품만',
#  '바로',
#  '결제할',
#  '수는',
#  '없을까요',
#  '이곳은',
#  '누구나',
#  '가지만',
#  '아무도',
#  '본',
#  '없는',
#  '곳이에요',
#  '나름',
#  '2018년',
#  '무사히',
#  '다녀왔어요',
#  '난',
#  '작은',
#  '것도',
#  '감사히',
#  '배웠습니다',
#  '내일',
#  '보자고',
#  '그랬잖아요',
#  '여름에는',
#  '만나야',
#  '그것을',
#  '막기',
#  '위해',
#  '과학자는',
#  '친환경적인',
#  '방법을',
#  '연구했어요',
#  '한옥',
#  '내부에',
#  'LED',
#  '램프를',
#  '장착하여',
#  '인테리어',
#  '효과를',
#  '배가시켰으며',
#  '야간에',
#  '수면',
#  '등으로도',
#  '활용',
#  '있도록',
#  '하였습니다',
#  '체크아웃',
#  '짐을',
#  '맡아주시는',
#  '게',
#  '가능한가요',
#  '앨리스는',
#  '언니와',
#  '있다가',
#  '굴로',
#  '뛰어들어',
#  '무의식의',
#  '판타지',
#  '세계로',
#  '들어가요',
#  '노란색',
#  '스티커가',
#  '붙어',
#  '제품이',
#  '행사제품입니다',
#  '싶지만',
#  '확신이',
#  '두려워',
#  '만일',
#  '한국에',
#  '방문한다면',
#  '탈을',
#  '사가길',
#  '바랍니다',
#  '성능',
#  '엔지니어의',
#  '프로그램으로부터든지',
#  '비행',
#  '매뉴얼에서부터',
#  '가져온',
#  '원래의',
#  '항공기',
#  '데이터입니다',
#  '그녀는',
#  '요청했으나',
#  '자세한',
#  '사진도',
#  '보여주지',
#  '않았어요',
#  '왜',
#  '오전에',
#  '일이',
#  '있는데',
#  '수업',
#  '하셨나요',
#  '제가',
#  '처리해야',
#  '사람들과',
#  '어울리지',
#  '못해요',
#  '드로잉이',
#  '감정의',
#  '배설물이라고',
#  '대략적인',
#  '양을',
#  '가능한',
#  '빨리',
#  '당신의',
#  '발송하기',
#  '이동해주시기',
#  '연구를',
#  '다양한',
#  '직업',
#  '분야의',
#  '데이터를',
#  '수집할',
#  '60퍼센트',
#  '이상',
#  '일',
#  '검출이',
#  '수단과',
#  '가리지',
#  '목적을',
#  '달성하려고',
#  '했어',
#  '안주하지',
#  '말고',
#  '자신의',
#  '내면의',
#  '소리에',
#  '귀',
#  '기울이며',
#  '우직하게',
#  '살라',
#  '너희',
#  '나라에서는',
#  '220V를',
#  '사용해',
#  '환경을',
#  '엘리베이터',
#  '대신',
#  '계단을',
#  '이용해보도록',
#  '시도했어요',
#  '오늘',
#  '만난다는',
#  '친구',
#  '여자인가요',
#  '약',
#  '12인치',
#  '사이즈가',
#  '팔렸습니다',
#  '기본',
#  '교재들은',
#  '반복',
#  '피드백',
#  '학습과',
#  '보충설명이',
#  '개인지도',
#  '시',
#  '사용이',
#  '편리하도록',
#  '편성되어',
#  '답변을',
#  '기다리고',
#  '보내준',
#  '사이즈와',
#  '가격에',
#  '동의',
#  '수요일에',
#  '하기',
#  '때문에',
#  '사무실에는',
#  '갈',
#  '수가',
#  '없다',
#  '너무',
#  '일어났나',
#  '봐요',
#  '반짝이는',
#  '보석과',
#  '금을',
#  '좋아하기도',
#  '친구와',
#  '약속을',
#  '토요일로',
#  '미루었어요',
#  '저희는',
#  '그냥',
#  '귀사와',
#  '인연을',
#  '생각합니다',
#  '오스트레일리아에서는',
#  '보통',
#  '살에',
#  '결혼을',
#  '하나요',
#  '지금은',
#  '팀을',
#  '만들',
#  '생각이',
#  '없습니다',
#  '날',
#  '못',
#  '믿겠다면',
#  '당신',
#  '친구한테',
#  '물어봐',
#  '번째로',
#  'Kidkraft에서',
#  '출시된',
#  'Rockin',
#  'Motorcycle입니다',
#  '부디',
#  '다음에',
#  '제게',
#  '다시',
#  '말해주세요',
#  '럭스는',
#  '100만',
#  '달러의',
#  '일반',
#  '책임',
#  '보험과',
#  '차고',
#  '관리자의',
#  '보험도',
#  '가지고',
#  '마음을',
#  '놀아요',
#  '당신과',
#  '사업을',
#  '하고',
#  '기업',
#  '공개',
#  '시장은',
#  '시점에',
#  '시작해서',
#  '추수감사절까지',
#  '호황을',
#  '이룬다',
#  '갑자기',
#  '손님이',
#  '바빠',
#  '또한',
#  '주문하지',
#  '않은',
#  '상품도',
#  '들어왔습니다',
#  '그러니',
#  '진행',
#  '중인',
#  '기업에서의',
#  '착수금',
#  '부분을',
#  '성사시킬',
#  '1번',
#  '부탁을',
#  '너랑',
#  '정이',
#  '참',
#  '들었나보다',
#  '널',
#  '걱정을',
#  '걸',
#  '보면',
#  '그날까지',
#  '데이터',
#  '제출에',
#  '불편함이',
#  '있으시면',
#  '이제부터는',
#  '모두',
#  '점심',
#  '식사',
#  '시간입니다',
#  'ABD가',
#  '개인화',
#  '기능이나',
#  '문서',
#  '다운로드',
#  '딜리버리',
#  '기능이',
#  '아닙니다',
#  '그들이',
#  '중국에',
#  '납품한',
#  '장비에',
#  '생겼어',
#  '때때로',
#  '집안을',
#  '어지럽히거나',
#  '물건을',
#  '망가뜨리지만',
#  '나를',
#  '행복하게',
#  '만들어줍니다',
#  '남편이',
#  '구청까지',
#  '옵니다',
#  '도면을',
#  '제공해주시면',
#  '오차를',
#  '줄일',
#  '손만',
#  '잡아줘도',
#  '행복해',
#  '축제가',
#  '열리면',
#  '친구들과',
#  '가보세요',
#  '이들의',
#  '서류가',
#  '필요한지',
#  '이해하기',
#  '어려워',
#  '교육에서는',
#  '용해도',
#  '지수에',
#  '대하여',
#  '교육이',
#  '피치',
#  '못할',
#  '사정으로',
#  '티켓을',
#  '환불받고',
#  '싶어',
#  '문의하게',
#  '됐습니다',
#  '한번',
#  '말씀해',
#  '주실래요',
#  '요새',
#  '조금만',
#  '움직여도',
#  '숨이',
#  '가빠집니다',
#  '그리고서',
#  '네트에',
#  '입장했을',
#  '불편함을',
#  '느꼈고',
#  '통제',
#  '불능',
#  '상태가',
#  '되었다',
#  '홍길동이라고',
#  '네',
#  '학교에서',
#  '사진을',
#  '원합니다',
#  '복수',
#  '명사',
#  '또는',
#  '셀',
#  '명사들을',
#  '비교할',
#  '그것들은',
#  '평범한',
#  '가정집',
#  '벽에',
#  '그려져',
#  '그에',
#  '대한',
#  '안',
#  '소문이',
#  '돌고',
#  '호텔에',
#  '전화해놨으니',
#  '받을',
#  '짠',
#  '음식이라든지',
#  '매운',
#  '음식은',
#  '싫어요',
#  '그러면',
#  '저녁에',
#  '있을까요',
#  '단지',
#  '거기에',
#  '앉아서',
#  '말을',
#  '계속해주길',
#  '멋진',
#  '노래이긴',
#  '하지만',
#  '상황에는',
#  '맞지',
#  '않는',
#  '듯',
#  '사람과',
#  '일생을',
#  '마쳤습니다',
#  '비울',
#  '필요가',
#  '서울의',
#  '분에',
#  '해가',
#  '뜨나요',
#  '꽃을',
#  '보내는',
#  '어떨까요',
#  '이곳에',
#  '지원한',
#  '이유는',
#  '자격증을',
#  '취득하여',
#  '공기업',
#  '금융계에',
#  '취업하고',
#  '싶기',
#  '때문입니다',
#  '동생들이랑',
#  '친해져야',
#  '합니까',
#  '설치',
#  '가이드',
#  '검수',
#  '요청',
#  '해당',
#  '사항',
#  '정보를',
#  '제공하지',
#  ...]

# %%
english_vocab
# Out:
# ['<pad>',
#  '<s>',
#  '</s>',
#  '<unk>',
#  'They',
#  'were',
#  'way',
#  'too',
#  'much',
#  'cynical',
#  'to',
#  'reality',
#  '.',
#  'You',
#  'can',
#  'use',
#  'a',
#  'public',
#  'parking',
#  'lot',
#  'near',
#  'the',
#  'stadium',
#  'Tickets',
#  'are',
#  'only',
#  'valid',
#  'for',
#  'admission',
#  'venue',
#  'listed',
#  'on',
#  'face',
#  'of',
#  'ticket',
#  'A',
#  'million',
#  'won',
#  'cash',
#  'coupon',
#  'will',
#  'be',
#  'raffled',
#  'off',
#  'customers',
#  'who',
#  'upload',
#  'good',
#  'review',
#  'Store',
#  'I',
#  'went',
#  'shopping',
#  'in',
#  'department',
#  'store',
#  'yesterday',
#  "'m",
#  'not',
#  'okay',
#  'at',
#  'all',
#  'right',
#  'now',
#  ',',
#  'so',
#  'want',
#  'alone',
#  'quietly',
#  'First',
#  'become',
#  'familiar',
#  'with',
#  'what',
#  'should',
#  'do',
#  'Ashburnham',
#  'and',
#  'would',
#  'like',
#  'my',
#  'best',
#  'Can',
#  'you',
#  'drive',
#  'truck',
#  '?',
#  'am',
#  'programmer',
#  'Jungsoo',
#  'Lee',
#  'easily',
#  'teach',
#  'disorderly',
#  'students',
#  'The',
#  'fixed',
#  'stance',
#  'help',
#  'relieve',
#  'back',
#  'pain',
#  'sending',
#  'this',
#  'email',
#  'ask',
#  'few',
#  'questions',
#  'have',
#  "n't",
#  'called',
#  'me',
#  'while',
#  'My',
#  'baby',
#  'feels',
#  'heat',
#  'very',
#  'maybe',
#  'is',
#  'why',
#  'he',
#  'has',
#  'trouble',
#  'his',
#  'skin',
#  'If',
#  'think',
#  'it',
#  "'s",
#  'been',
#  'busy',
#  'tough',
#  'day',
#  'above',
#  'sentence',
#  'Jisung',
#  'typed',
#  'means',
#  'meet',
#  'up',
#  'early',
#  'buy',
#  'enjoy',
#  'swimming',
#  'received',
#  'great',
#  'energy',
#  'opening',
#  'Busan',
#  'from',
#  'them',
#  'friend',
#  'dancing',
#  'Is',
#  'there',
#  'anyone',
#  'drove',
#  'home',
#  'study',
#  'hard',
#  'also',
#  'weekend',
#  'Whenever',
#  'was',
#  'father',
#  'through',
#  'fascinating',
#  'entertaining',
#  'events',
#  'This',
#  'cavity',
#  'calling',
#  'candy',
#  'made',
#  'dish',
#  'family',
#  'played',
#  'cousins',
#  'Chuseok',
#  'It',
#  'says',
#  'accommodation',
#  'booked',
#  'everything',
#  "'ve",
#  'enrolled',
#  '2010',
#  'but',
#  'got',
#  'readmitted',
#  'second',
#  'semester',
#  'first',
#  'lecture',
#  'Let',
#  'know',
#  'updated',
#  'schedule',
#  'flights',
#  'delayed',
#  'because',
#  'weather-it',
#  'fault',
#  'Ken',
#  'come',
#  'solve',
#  'problem',
#  'What',
#  'most',
#  'practical',
#  'approach',
#  'situation',
#  'liked',
#  'Do',
#  'try',
#  'straight',
#  'anymore',
#  'take',
#  'photos',
#  'any',
#  'plans',
#  'today',
#  'introducing',
#  'about',
#  'fado',
#  'which',
#  'Portuguese',
#  'popular',
#  'folk',
#  'song',
#  'time',
#  'your',
#  'Your',
#  'inquiries',
#  'diesel',
#  'solution',
#  'solved',
#  'by',
#  'applying',
#  'our',
#  'IoT',
#  'Gateway',
#  'terminal',
#  'England',
#  '6',
#  'months',
#  'ago',
#  'going',
#  'Korea',
#  'After',
#  'mask',
#  'pack',
#  'let',
#  'ample',
#  'absorb',
#  'tapping',
#  'around',
#  'eyes',
#  'whole',
#  'Thanks',
#  'visiting',
#  'booth',
#  'Dubai',
#  'exhibition',
#  'last',
#  'week',
#  'Feel',
#  'wastes',
#  'wash',
#  'out',
#  'disappear',
#  'foam',
#  'picture',
#  'taken',
#  'campus',
#  'rooftop',
#  'couple',
#  'days',
#  'We',
#  'get',
#  'rid',
#  'passive',
#  'part',
#  'form',
#  'creativity',
#  'college',
#  'student',
#  'rather',
#  'clever',
#  'than',
#  'intelligent',
#  'jacket',
#  'type',
#  'platform',
#  'western',
#  'sea',
#  'military',
#  'base',
#  'change',
#  'if',
#  'give',
#  'some',
#  'making',
#  'one',
#  'an',
#  'airplane',
#  'once',
#  'need',
#  'that',
#  'product',
#  'urgently',
#  'At',
#  'same',
#  'World',
#  'Health',
#  'Organization',
#  'judged',
#  'American',
#  'healthcare',
#  'system',
#  '30th',
#  'world',
#  'extraterritorial',
#  'area',
#  'here',
#  'Please',
#  'tell',
#  'where',
#  'nearest',
#  'market',
#  'classical',
#  'representative',
#  'traditional',
#  'Korean',
#  'dance',
#  "'ll",
#  'car',
#  'Around',
#  'end',
#  'year',
#  'make',
#  'reservation',
#  'advance',
#  'May',
#  'pool',
#  'evening',
#  'as',
#  'well',
#  'So',
#  'In',
#  'life',
#  "'re",
#  'responsible',
#  'shape',
#  'pocket',
#  'crumpled',
#  'lining',
#  'wrist',
#  'tapering',
#  'allow',
#  'freedom',
#  'movement',
#  '1km',
#  'left',
#  'destination',
#  'Many',
#  'subway',
#  'lines',
#  'running',
#  'purpose',
#  'competition',
#  'look',
#  'people',
#  'they',
#  'their',
#  'brain',
#  'rest',
#  'smartphones',
#  'internet',
#  'did',
#  'say',
#  'food',
#  'Shinsegae',
#  'Department',
#  'thought',
#  'lens',
#  'already',
#  'As',
#  'explained',
#  'advertisements',
#  'lead',
#  'believe',
#  'something',
#  'different',
#  'truth',
#  'Coming',
#  'impossible',
#  'hanging',
#  'helping',
#  'mother',
#  'work',
#  'really',
#  'exams',
#  'go',
#  'Seoul',
#  'DongSeong',
#  'high',
#  'school',
#  'And',
#  'how',
#  'husband',
#  'Hey',
#  'Dabong',
#  'Yim',
#  'wake',
#  'breakfast',
#  'used',
#  'noisy',
#  'nothing',
#  'shellfish',
#  'barbecue',
#  'restaurants',
#  'Maybe',
#  'difficult',
#  'satisfactory',
#  'progress',
#  'office',
#  'hour',
#  'nine',
#  'hours',
#  'average',
#  'When',
#  'disposing',
#  'discharge',
#  'completely',
#  'then',
#  'recycle',
#  'awarenesses',
#  'fundamental',
#  'step',
#  'forward',
#  'small',
#  'medium-sized',
#  'enterprises',
#  'attraction',
#  'soccer',
#  'Inside',
#  'play',
#  'exciting',
#  'music',
#  'feel',
#  'pleasured',
#  'we',
#  'arrived',
#  'town',
#  'banks',
#  'closed',
#  'sent',
#  'cancel',
#  'deal',
#  'locked',
#  'door',
#  'key',
#  'inside',
#  'Are',
#  'willing',
#  'table',
#  'settings',
#  'just',
#  'enter',
#  'password',
#  'sign',
#  'send',
#  'message',
#  'culture',
#  'affects',
#  'views',
#  'regarding',
#  'There',
#  'several',
#  'things',
#  'consider',
#  'when',
#  'explaining',
#  'Japanese',
#  'occupation',
#  'He',
#  'showed',
#  'love',
#  'doing',
#  'independence',
#  'movements',
#  'Koreans',
#  'families',
#  'leave',
#  'travel',
#  'earlier',
#  'us',
#  'Loving',
#  'yourself',
#  'begin',
#  'loving',
#  'How',
#  'Terran',
#  'Starcraft',
#  'large',
#  'hit',
#  'someone',
#  'ran',
#  'away',
#  'Using',
#  'persons',
#  'politically',
#  'rationally',
#  'understood',
#  'order',
#  'necessary',
#  'materials',
#  'supply',
#  'business',
#  'definitelyregret',
#  'Ca',
#  'goods',
#  'cart',
#  'pay',
#  'current',
#  'place',
#  'everyone',
#  'goes',
#  'never',
#  'seen',
#  '2018',
#  'trip',
#  'quite',
#  'successful',
#  'learned',
#  'appreciate',
#  'said',
#  'see',
#  'tomorrow',
#  'must',
#  'together',
#  'summer',
#  'To',
#  'prevent',
#  'many',
#  'scientists',
#  'researched',
#  'eco-friendly',
#  'upgraded',
#  'interior',
#  'design',
#  'effectiveness',
#  'installing',
#  'LED',
#  'lamp',
#  'Hanok',
#  'bed',
#  'light',
#  'possible',
#  'care',
#  'baggage',
#  'after',
#  'check-out',
#  'Alice',
#  'her',
#  'sister',
#  'she',
#  'dives',
#  'into',
#  'cave',
#  'unconscious',
#  'fantasy',
#  'yellow',
#  'stickers',
#  'products',
#  'sale',
#  '’',
#  'd',
#  'afraid',
#  'sure',
#  'visit',
#  'original',
#  'aircraft',
#  'performance',
#  'data',
#  'retrieved',
#  'either',
#  'Performance',
#  'Engineer',
#  's',
#  'Program',
#  'or',
#  'Flight',
#  'Manuals',
#  'She',
#  'even',
#  'show',
#  'detailed',
#  'although',
#  'asked',
#  'came',
#  'morning',
#  'class',
#  'though',
#  'had',
#  'other',
#  'along',
#  'others',
#  'drawing',
#  'excretion',
#  'emotion',
#  'transfer',
#  'open',
#  'amount',
#  'soon',
#  'able',
#  'release',
#  'Through',
#  'research',
#  'could',
#  'collect',
#  'various',
#  'job',
#  'fields',
#  'detectable',
#  '60',
#  'percent',
#  'tried',
#  'achieve',
#  'goal',
#  'Listen',
#  'inner',
#  'voice',
#  'stay',
#  'foolish',
#  'settle',
#  'country',
#  '220',
#  'voltage',
#  'being',
#  'stairs',
#  'instead',
#  'elevator',
#  'environment',
#  'meeting',
#  'girl',
#  'About',
#  '12inch',
#  'sizes',
#  'sold',
#  'Basic',
#  'textbooks',
#  'immediate',
#  'repetitive',
#  'feedback',
#  'learning',
#  'supplementary',
#  'explanation',
#  'organized',
#  'giving',
#  'personal',
#  'guidances',
#  'waiting',
#  'response',
#  'agree',
#  'size',
#  'price',
#  'Wednesday',
#  'shining',
#  'jewels',
#  'gold',
#  'appointment',
#  'Saturday',
#  'relationship',
#  'company',
#  'age',
#  'getting',
#  'married',
#  'Australia',
#  'team',
#  'ca',
#  'trust',
#  'Rockin',
#  'Motorcycle',
#  'Kidkraft',
#  'again',
#  'later',
#  'Luxe',
#  '$',
#  '1',
#  'general',
#  'liability',
#  'insurance',
#  'garage',
#  'keepers',
#  'person',
#  'heart',
#  'IPO',
#  'tends',
#  'pick',
#  'between',
#  'Thanksgiving',
#  'Day',
#  'rushed',
#  'suddenly',
#  'Also',
#  'more',
#  'DEPOSIT',
#  'another',
#  'currently',
#  'underway',
#  'close',
#  'seeing',
#  'worry',
#  'uncomfortable',
#  'submitting',
#  'date',
#  'lunchtime',
#  'ABD',
#  'no',
#  'function',
#  'personalization',
#  'download',
#  'delivery',
#  'tools',
#  'provided',
#  'China',
#  'problems',
#  'Sometimes',
#  'mess',
#  'house',
#  'break',
#  'stuff',
#  'happy',
#  'drives',
#  'district',
#  'Errors',
#  'reduced',
#  'layouts',
#  'holding',
#  'hand',
#  'Try',
#  'these',
#  'festivals',
#  'friends',
#  'understand',
#  'documents',
#  'needed',
#  'lesson',
#  'solubility',
#  'parameters',
#  'inquiry',
#  'refund',
#  'due',
#  'unavoidable',
#  'circumstances',
#  'Beg',
#  'pardon',
#  'breathless',
#  'move',
#  'little',
#  'bit',
#  'net',
#  'felt',
#  'control',
#  'Hong',
#  'Gil',
#  'Dong',
#  'took',
#  'For',
#  'plural',
#  'uncountable',
#  'nouns',
#  'compare',
#  'quantities',
#  'These',
#  'drawn',
#  'wall',
#  'normal',
#  'bad',
#  'rumor',
#  'him',
#  'hotel',
#  'recieve',
#  'salty',
#  'spicy',
#  'sit',
#  'hoping',
#  'over',
#  'Amazing',
#  'situationally',
#  'inappropriate',
#  'ended',
#  'two',
#  'vacant',
#  'mind',
#  'Exactly',
#  'does',
#  'sunrise',
#  'flowers',
#  'reason',
#  'applied',
#  'certificate',
#  'enterprise',
#  'financial',
#  'Before',
#  'younger',
#  'sisters',
#  'brothers',
#  'sorry',
#  'provide',
#  'relevant',
#  'information',
#  'requesting',
#  'inspection',
#  'installation',
#  'guideline',
#  'Sales',
#  'decreased',
#  'quarter',
#  'sidewalk',
#  'pedestrians',
#  'roadway',
#  'still',
#  'sleepy',
#  'ready',
#  'finally',
#  'steering',
#  'wheel',
#  'C',
#  'annually',
#  'recruits',
#  'new',
#  'employees',
#  'countries',
#  'twitter',
#  'account',
#  '7',
#  'languages',
#  'looked',
#  'airline',
#  'regulation',
#  'weight',
#  'luggage',
#  'e',
#  '23kg',
#  'normally',
#  'safely',
#  'living',
#  'facility',
#  'inconveniences',
#  'agreement',
#  'companies',
#  'dismiss',
#  'mere',
#  'youngster',
#  'tracking',
#  'Numbers',
#  'please',
#  'turn',
#  'lights',
#  'third',
#  'floor',
#  'working',
#  'visa',
#  'Last',
#  'synchronization',
#  'mobile',
#  'phone',
#  'kept',
#  'promise',
#  'until',
#  'toast',
#  'done',
#  'enough',
#  'regretful',
#  'support',
#  'editor',
#  'experience',
#  'became',
#  'opportunity',
#  'find',
#  'dream',
#  'Its',
#  'premium',
#  'special',
#  'microfiber',
#  'moisturizes',
#  'nourishes',
#  'intensively',
#  'short',
#  'flirting',
#  'club',
#  'number',
#  'justifies',
#  'seller',
#  'understanding',
#  'text',
#  'An',
#  'indifference',
#  'curve',
#  'counter',
#  'line',
#  'total',
#  'utility',
#  'constant',
#  'camping',
#  'island',
#  'reacted',
#  'ridiculous',
#  'app',
#  'listen',
#  'DEP',
#  'program',
#  'Apple',
#  'rolled',
#  'corrected',
#  'tariff',
#  'carved',
#  'initials',
#  'guess',
#  'run',
#  'heard',
#  'registered',
#  'exam',
#  'effort',
#  'better',
#  'chivalry',
#  'rules',
#  'dictated',
#  'knights',
#  "'",
#  'behavior',
#  'towards',
#  'process',
#  'likely',
#  'sick',
#  'caught',
#  'cold',
#  '3',
#  'choices',
#  'each',
#  'shall',
#  'Gimchi-jjigae',
#  'pride',
#  'menu',
#  'Myeongwol',
#  'eat',
#  'all-you-can-eat',
#  'determined',
#  'image',
#  'depending',
#  'bought',
#  'Although',
#  'self-esteem',
#  'having',
#  'higher',
#  'reading',
#  'book',
#  'Among',
#  'radio',
#  'programs',
#  "'professional",
#  'pop',
#  'compared',
#  "'Korean",
#  'related',
#  'large-sum',
#  'retail',
#  'export',
#  'e-mail',
#  'Kakaotalk',
#  'quick',
#  'replies',
#  'Casio',
#  'Tsim',
#  'Sa',
#  'Tsui',
#  'That',
#  'alphabet',
#  'write',
#  'English',
#  'surface',
#  'water',
#  'resistant',
#  'dirty',
#  'parts',
#  'cleaned',
#  'damp',
#  'cloth',
#  '9th',
#  'god',
#  'talented',
#  'among',
#  'gods',
#  'future',
#  'depends',
#  'Suppose',
#  ...]

# %%
def batch(iterable, n=1):
    args = [iter(iterable)] * n
    return zip_longest(*args)


def pad_tensor(vec, pad, value=0, dim=0):
    """
    pad token으로 채우는 용도 
    args:
        vec - tensor to pad
        pad - the size to pad to
        dim - dimension to pad
    return:
        a new tensor padded to 'pad' in dimension 'dim'
    """
    pad_size = pad - vec.shape[0] # 문장 길이에서 모자라는 만큼 

    if len(vec.shape) == 2:
        zeros = torch.ones((pad_size, vec.shape[-1])) * value
    elif len(vec.shape) == 1:
        zeros = torch.ones((pad_size,)) * value
    else:
        raise NotImplementedError
    return torch.cat([torch.Tensor(vec), zeros], dim=dim)

# %%
def pad_collate(batch, values=(0, 0), dim=0):
    """
    데이터 로더에 들어가기전에 batch화 할 때 거치는 함수 
    args:
        batch - list of (tensor, label)
    reutrn:
        xs - a tensor of all examples in 'batch' after padding
        ys - a LongTensor of all labels in batch
        ws - a tensor of sequence lengths
    """

    # [[s1, s2], [s1, s2], [s1, s2], ...]

    sequence_lengths = torch.Tensor([int(x[0].shape[dim]) for x in batch]) # 각 batch 마다 길이를 얻어내고 
    sequence_lengths, xids = sequence_lengths.sort(descending=True) # 감소하는 순서로 정렬
    target_lengths = torch.Tensor([int(x[1].shape[dim]) for x in batch])

    # find longest sequence (가장 긴 sequence의 길이를 구함 )
    src_max_len = max(map(lambda x: x[0].shape[dim], batch))
    tgt_max_len = max(map(lambda x: x[1].shape[dim], batch))

    # pad according to max_len (max length 만큼 padd를 추가 )
    # [[x, y], [x, y], [x, y], ... ]
    batch = [(pad_tensor(x, pad=src_max_len, dim=dim), pad_tensor(y, pad=tgt_max_len, dim=dim)) for (x, y) in batch]

    # stack all
    xs = torch.stack([x[0] for x in batch], dim=0)
    ys = torch.stack([x[1] for x in batch], dim=0) # 하나의 tensor로 만들어줌

    # transformer에서는 잘 사용하지 않음(별다른 영향이 없음). RNN에서 주로 쓰임. 
    # 불필요한 계산을 없애기 위함 (pad)
    xs = xs[xids].contiguous() # decreasing order로 다시 나열 
    ys = ys[xids].contiguous() # xids 와 같은 순서로 

    target_lengths = target_lengths[xids] 
    return xs.long(), ys.long(), sequence_lengths.int(), target_lengths.int() # int32 / long: int64


class ToyDataset(data.Dataset): # 한 -> 영 
    """
    https://talbaumel.github.io/blog/attention/
    """
    def __init__(self,  ko_path, en_path , ko_word2id, en_word2id):
        with open(ko_path, "rb") as f:
            self.ko_seqs = pickle.load(f)
        with open(en_path, "rb") as f:
            self.en_seqs = pickle.load(f)
        self.ko_word2id = ko_word2id
        self.en_word2id = en_word2id


    def __len__(self):
        return len(self.ko_seqs)

    def __getitem__(self, index):
        ko_seqs = self.ko_seqs[index]
        en_seqs = self.en_seqs[index]
        ko_seqs = self.process(ko_seqs, self.ko_word2id)
        en_seqs = self.process(en_seqs, self.en_word2id)

        # 한국어 문장 -> 영어 문장 
        # <s> 한국어 문장 인덱스들 </s> 
        # <s> 영어 문장 인덱스들 </s>

        return ko_seqs, en_seqs       

    def process(self, seq, word2id):

        # <s> 한국어 문장 인덱스들 </s> 
        # <s> 영어 문장 인덱스들 </s>
        sequence = []
        sequence.append(word2id["<s>"]) # <SOS>
        words = seq.strip().split(' ') # space 단위로 쪼갬 
        for word in words:
            if len(sequence) < model_config.max_len:
                if word in word2id:
                    sequence.append(word2id[word]) # 만약 vocabulary에 있으면 ,해당 index 넣기
                else: # 없으면 <unk> 넣기 
                    sequence.append(3) # replace by <unk> token 
            else:
                break
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence

# %%
sample_config = { # 적당한 하이퍼파라미터
    "dim": 32,
    "dim_ff": 32,
    "n_layers": 2,
    "p_drop_attn": 0.1,
    "n_heads": 4,
    "p_drop_hidden": 0.1,
    "max_len": 30,
    "n_segments": 2,
    "vocab_size": 30522,
    "batch_size": 32
}

class AttributeDict(dict):
    def __getattr__(self, name):
        return self[name]

model_config = AttributeDict(sample_config)
model = Transformer(model_config)
model = model.cuda()
# out = model(sample[0].cuda(),sample[0].cuda())
# out.size()

# %%
optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0) # pad token(0번 토큰) 무시

# %%
dataset = ToyDataset("train_korean.pkl", "train_english.pkl", korean_word2id, english_word2id)
train_loader = data.DataLoader(dataset, batch_size=model_config.batch_size, shuffle=True, collate_fn=pad_collate, drop_last=True)

# %%
# 학습하기 
model.train()
for epoch in range(10):
    loss_list =[]
    for idx, batch in enumerate(train_loader):
        x, y, x_len, y_len = batch
        x = x.cuda()
        y = y.cuda()
        logits = model(x, y[:,:-1]) # </s>(<EOS>) token 제외 
        loss = loss_fn(logits.view(-1,len(english_vocab)) , 
                       y[:,1:].contiguous().view(-1)) # loss 구하기 우리는 cross entropy 사용 
                       # <s>(<SOS>) token 제외
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        loss_list.append(loss.item())
        
        if (idx+1) % 400 == 0 :
            print('epoch {} iteration {}/{} loss {:.4f}'.format(epoch+1, idx+1, len(train_loader), np.mean(loss_list)))
            loss_list=[]
            
        if (idx+1) % 2000 == 0:
            with torch.no_grad():
                # greedy_decoding
                ## 생성할 때 확률이 높은 순서대로 나열하는 것 
                # beam search
                ## 모든 경우의 수의 확률을 계산해 가장 높은 것을 채택 

                greedy_pred = model.greedy_decoding(x[0].unsqueeze(0))
            greedy_pred_indices = greedy_pred[0].data.cpu().tolist()
            pred_indices = logits[0].argmax(-1).data.cpu().tolist()
            input_indices = x[0].data.cpu().tolist()
            label_indices = y[0].data.cpu().tolist()
            
            if 2 in pred_indices:
                greedy_pred_len = pred_indices.index(2)
            else:
                greedy_pred_len = 128
            
            if 2 in pred_indices:
                pred_len = pred_indices.index(2)
            else:
                pred_len = 128

            if 2 in input_indices:
                input_len = input_indices.index(2)
            else:
                input_len = 128

            if 2 in label_indices:
                label_len = label_indices.index(2)
            else:
                label_len = 128
            
            greedy_pred_words = [english_id2word[idx] for i, idx in enumerate(greedy_pred_indices) if i<= greedy_pred_len]
            pred_words = [english_id2word[idx] for i, idx in enumerate(pred_indices) if i<=pred_len]
            input_words = [korean_id2word[idx] for i, idx in enumerate(input_indices) if i<=input_len]
            label_words = [english_id2word[idx] for i, idx in enumerate(label_indices) if i<=label_len]

            print('=====================================')
            print('입력:{}'.format(' '.join(input_words[1:-1])))
            print('출력(teacher forcing):{}'.format(' '.join(pred_words[:-1])))
            print('출력(greedy decoding):{}'.format(' '.join(greedy_pred_words[:-1])))
            print('정답:{}'.format(' '.join(label_words[1:-1])))
            print('=====================================')
# Out:
# epoch 1 iteration 400/11250 loss 6.9128
# epoch 1 iteration 800/11250 loss 5.7098
# epoch 1 iteration 1200/11250 loss 5.4449
# epoch 1 iteration 1600/11250 loss 5.3082
# epoch 1 iteration 2000/11250 loss 5.1909
# =====================================
# 입력:이것은 제가 분석업무를 수행할 때 상사 또는 고객사의 니즈를 더욱 더 명확히 파악할 수 있으리라 생각합니다 .
# 출력(teacher forcing):I do you can be a to be to to same , the friend . the friend . I can n't same .
# 출력(greedy decoding):I 'm going to the same to the same .
# 정답:I think I will be able to clearly tell the needs of my clients or my boss when I do the analysis .
# =====================================
# epoch 1 iteration 2400/11250 loss 5.0978
# epoch 1 iteration 2800/11250 loss 5.0465
# epoch 1 iteration 3200/11250 loss 4.9885
# epoch 1 iteration 3600/11250 loss 4.9441
# epoch 1 iteration 4000/11250 loss 4.9029
# =====================================
# 입력:이러한 이유로 , FTA는 한국 경제에 많은 도움이 되고 있다고 생각하며 FTA가 계속 이루어져야 한다고 생각해요 .
# 출력(teacher forcing):The , , , the have the the product , not important . be product . of the world . be .
# 출력(greedy decoding):The product of the product , and the product , the product is a lot of the world .
# 정답:For these reasons , I think that the FTA is very helpful to the Korean economy and the FTA should continue .
# =====================================
# epoch 1 iteration 4400/11250 loss 4.8782
# epoch 1 iteration 4800/11250 loss 4.8641
# epoch 1 iteration 5200/11250 loss 4.8162
# epoch 1 iteration 5600/11250 loss 4.7902
# epoch 1 iteration 6000/11250 loss 4.7814
# =====================================
# 입력:이 축제에는 매년 많은 눈 조각상이 세워지고 , 이 조각상을 위해 5t의 트럭 7,000대가 동원된다 .
# 출력(teacher forcing):This , , , a , this year , the not to , to the to the , .
# 출력(greedy decoding):This product is a lot of the product , and the product is a new product of the world
# 정답:Numerous ice sculptures are created in this festival and 7,000 5 ton trucks are employed for this artworks .
# =====================================
# epoch 1 iteration 6400/11250 loss 4.7562
# epoch 1 iteration 6800/11250 loss 4.7273
# epoch 1 iteration 7200/11250 loss 4.7003
# epoch 1 iteration 7600/11250 loss 4.6961
# epoch 1 iteration 8000/11250 loss 4.6877
# =====================================
# 입력:미안하지만 비행기로 오는 제품에 관한 부분은 운송료나 제품의 가격에 조금이라도 지원이 있었으면 합니다 .
# 출력(teacher forcing):I have going to I will you are n't you the people the the product of the . of is the . the of
# 출력(greedy decoding):I have to have a lot of the product of the product and the product is not a new company .
# 정답:I 'm sorry but I wish you could give us some support for the transportation and product prices which are shipped via air .
# =====================================
# epoch 1 iteration 8400/11250 loss 4.6604
# epoch 1 iteration 8800/11250 loss 4.6581
# epoch 1 iteration 9200/11250 loss 4.6526
# epoch 1 iteration 9600/11250 loss 4.6188
# epoch 1 iteration 10000/11250 loss 4.6342
# =====================================
# 입력:하지만 시간이 지나면 변제의 일부분은 자연스럽게 심재가 되고 , 스스로 새롭게 생성하며 생육을 지속시킨다 .
# 출력(teacher forcing):But , the the , the , the world is , a lot , and . and the of world .
# 출력(greedy decoding):But , it is a lot of the same time , and the best and the most .
# 정답:However , over time , part of the reimbursement naturally becomes a psychological , self-creating , and sustains the reproduction .
# =====================================
# epoch 1 iteration 10400/11250 loss 4.5913
# epoch 1 iteration 10800/11250 loss 4.5826
# epoch 1 iteration 11200/11250 loss 4.5703
# epoch 2 iteration 400/11250 loss 4.4672
# epoch 2 iteration 800/11250 loss 4.4803
# epoch 2 iteration 1200/11250 loss 4.4662
# epoch 2 iteration 1600/11250 loss 4.4258
# epoch 2 iteration 2000/11250 loss 4.4469
# =====================================
# 입력:지금 부모님과 살고 있거나 기숙사에 살고 계신 분들도 언젠가 집을 구하게 될 날이 오겠죠 .
# 출력(teacher forcing):I of the have have have in the friends and a in the good . and I are be much . . a friend time .
# 출력(greedy decoding):I 'm going to the same time for the same time .
# 정답:Some of you may still live with your parents or live in a dormitory , but you will too someday move into your own house .
# =====================================
# epoch 2 iteration 2400/11250 loss 4.4339
# epoch 2 iteration 2800/11250 loss 4.4175
# epoch 2 iteration 3200/11250 loss 4.4251
# epoch 2 iteration 3600/11250 loss 4.4089
# epoch 2 iteration 4000/11250 loss 4.4332
# =====================================
# 입력:60이 넘으신 손님은 확률상 라식이나 라섹보다는 icl 이나 노안 교정 수술의 가능성이 큽니다 .
# 출력(teacher forcing):The the who the , the is the , and the than to the to the .
# 출력(greedy decoding):The product is the same of the product and the same time .
# 정답:For people over 60 , ICL or presbyopic correction is more recommendable than LASIK or LASEK .
# =====================================
# epoch 2 iteration 4400/11250 loss 4.3883
# epoch 2 iteration 4800/11250 loss 4.3824
# epoch 2 iteration 5200/11250 loss 4.3767
# epoch 2 iteration 5600/11250 loss 4.3655
# epoch 2 iteration 6000/11250 loss 4.3519
# =====================================
# 입력:편하게 마음에 드는 물건을 고를 수도 있고 쉽고 빠르게 구매할 수 있기 때문에 나는 온라인쇼핑을 좋아합니다 .
# 출력(teacher forcing):So think to and mall I can not the other and can to and the 's a to I .
# 출력(greedy decoding):I can not send the product of the same as a problem .
# 정답:I like online shopping because I can choose any product I want freely and it 's easy and fast .
# =====================================
# epoch 2 iteration 6400/11250 loss 4.3627
# epoch 2 iteration 6800/11250 loss 4.3638
# epoch 2 iteration 7200/11250 loss 4.3605
# epoch 2 iteration 7600/11250 loss 4.3513
# epoch 2 iteration 8000/11250 loss 4.3501
# =====================================
# 입력:저는 현재 커버 일러스트들을 그리고 있는데 , 이 작업비용을 제 바뀐 통장으로 지급받고 싶어서 당신에게 연락드립니다 .
# 출력(teacher forcing):I 'm sending that this the , but I 'm going you . you this case . . the company . .
# 출력(greedy decoding):I 'm going to see the first , and I 'm going to you .
# 정답:I 'm currently drawing cover illustrations , and I 'm contacting you to receive this work fee in my changed account .
# =====================================
# epoch 2 iteration 8400/11250 loss 4.3334
# epoch 2 iteration 8800/11250 loss 4.3301
# epoch 2 iteration 9200/11250 loss 4.3276
# epoch 2 iteration 9600/11250 loss 4.3210
# epoch 2 iteration 10000/11250 loss 4.3069
# =====================================
# 입력:제 생각에 제가 백화점에 가서 살 수 있는 5가지는 장난감 , 음식 , 화장품 , 옷 , 책이 있습니다 .
# 출력(teacher forcing):I the dream , I years are can see the the year store . the , and , and . and , I ,
# 출력(greedy decoding):I 'm going to be a Korean of the world , and I have to the most of the world .
# 정답:In my opinion , 5 things I can buy at a department store are toys , food , cosmetics , clothes and books .
# =====================================
# epoch 2 iteration 10400/11250 loss 4.3313
# epoch 2 iteration 10800/11250 loss 4.3179
# epoch 2 iteration 11200/11250 loss 4.3093
# epoch 3 iteration 400/11250 loss 4.2047
# epoch 3 iteration 800/11250 loss 4.2173
# epoch 3 iteration 1200/11250 loss 4.2099
# epoch 3 iteration 1600/11250 loss 4.2119
# epoch 3 iteration 2000/11250 loss 4.1974
# =====================================
# 입력:대인관계 문제로 인한 생산성 감소 역시 도입 전 31 % 에서 도입 후 23 % 로 개선된 것으로 나타났습니다 .
# 출력(teacher forcing):The government the the is the % , the the , the and of the % of the company .
# 출력(greedy decoding):The company is a company and the company and the company of the company and the company is the company
# 정답:The decline of productivity by interpersonal problems was also improved from 31 % to 23 % after the introduction .
# =====================================
# epoch 3 iteration 2400/11250 loss 4.2153
# epoch 3 iteration 2800/11250 loss 4.1914
# epoch 3 iteration 3200/11250 loss 4.1919
# epoch 3 iteration 3600/11250 loss 4.2003
# epoch 3 iteration 4000/11250 loss 4.1983
# =====================================
# 입력:나이테는 과거에서 현재로 올라온 것이지만 지혜로운 사람에게는 앞으로 삶을 살아가는 인생의 새로운 리듬이기도 해요 .
# 출력(teacher forcing):The , and not the best , the and the future , and the the new person . and is a to new life . the . the future
# 출력(greedy decoding):The reason is the best to the first time to the best of the same as a new company .
# 정답:Annual rings are from the past and remain to the present , but to a wise person , it is also a new rhythm of life for the future
# =====================================
# epoch 3 iteration 4400/11250 loss 4.1973
# epoch 3 iteration 4800/11250 loss 4.1897
# epoch 3 iteration 5200/11250 loss 4.1879
# epoch 3 iteration 5600/11250 loss 4.2091
# epoch 3 iteration 6000/11250 loss 4.1890
# =====================================
# 입력:제 입장은 게임 중독이나 범죄 등 악용될 수 있는 점이 많기 때문에 어린 학생들의 스마트폰사용은 금지하여야 한다는 것입니다 .
# 출력(teacher forcing):I life , a the , can be a to the the . of . be able . the . . the .
# 출력(greedy decoding):I think I can have to be able to see my own and I think of the world .
# 정답:My stance is that young students should be prohibited from using smartphones because phones can be abused by game addiction or crime .
# =====================================
# epoch 3 iteration 6400/11250 loss 4.1664
# epoch 3 iteration 6800/11250 loss 4.1867
# epoch 3 iteration 7200/11250 loss 4.1944
# epoch 3 iteration 7600/11250 loss 4.1745
# epoch 3 iteration 8000/11250 loss 4.1857
# =====================================
# 입력:바다 오염을 복구하는 비용은 네가 물이나 플라스틱 백을 사는 비용보다 훨씬 더 많이 든다 .
# 출력(teacher forcing):The , the the same of , , and than the the of . the . .
# 출력(greedy decoding):The main product is a lot of the same time that you can be able to use
# 정답:Trying to recover the polluted sea costs much more than buying some water or plastic bags .
# =====================================
# epoch 3 iteration 8400/11250 loss 4.1698
# epoch 3 iteration 8800/11250 loss 4.1549
# epoch 3 iteration 9200/11250 loss 4.1649
# epoch 3 iteration 9600/11250 loss 4.1604
# epoch 3 iteration 10000/11250 loss 4.1428
# =====================================
# 입력:고객이 내게 부당한 비판을 하고 있다는 슬픈 생각은 버리고 고객의 컴플레인을 해결하는 것이 가장 중요하다고 생각했습니다 .
# 출력(teacher forcing):I 's the to be the information to and and time of the a own . .
# 출력(greedy decoding):I think the best is the best for the first time , but it is the first
# 정답:It is important to solve the customers ' problems first instead of taking their complaints personally .
# =====================================
# epoch 3 iteration 10400/11250 loss 4.1615
# epoch 3 iteration 10800/11250 loss 4.1317
# epoch 3 iteration 11200/11250 loss 4.1540
# epoch 4 iteration 400/11250 loss 4.0709
# epoch 4 iteration 800/11250 loss 4.0753
# epoch 4 iteration 1200/11250 loss 4.0573
# epoch 4 iteration 1600/11250 loss 4.0476
# epoch 4 iteration 2000/11250 loss 4.0608
# =====================================
# 입력:그래서 너는 제일 쉬워 보이는 나에게 연락 한 거고 난 또 안쓰러워 수업 끝나고 피자 먹고 싶다고 해서 피자를 사 갔다 .
# 출력(teacher forcing):So , can me to you to go a most , I had on , a to ,
# 출력(greedy decoding):So I will be able to go to the class , and I want to the last time
# 정답:So you contacted me which seems to be the easiest and I felt sorry for you again . I wanted to eat pizza after class , so I bought
# =====================================
# epoch 4 iteration 2400/11250 loss 4.0728
# epoch 4 iteration 2800/11250 loss 4.0618
# epoch 4 iteration 3200/11250 loss 4.0563
# epoch 4 iteration 3600/11250 loss 4.0570
# epoch 4 iteration 4000/11250 loss 4.0843
# =====================================
# 입력:나는 내 꿈을 이루기 위해 자격증 공부를 열심히 하였고 많은 체험을 할 수 있도록 노력했고 , 유아 관련의 책도 많이 읽었어요 .
# 출력(teacher forcing):I I my parents , I can hard to a lot of I to study to experiences . I I . years . to the best .
# 출력(greedy decoding):I thought I was in the future , but I had a lot of life and I had a lot of life and who I can learn
# 정답:To achieve my dream , I studied hard for a certificate , tried to have various experiences , and read many books related to the children .
# =====================================
# epoch 4 iteration 4400/11250 loss 4.0810
# epoch 4 iteration 4800/11250 loss 4.0627
# epoch 4 iteration 5200/11250 loss 4.0630
# epoch 4 iteration 5600/11250 loss 4.0629
# epoch 4 iteration 6000/11250 loss 4.0395
# =====================================
# 입력:생산에서 없어져야 할 부품들은 내가 생산 BOM에서 제거할 수 있기 전에 재고로 반송되어야 해요 .
# 출력(teacher forcing):The final of I to be a , the company of to the used to the . the have be the . the same of .
# 출력(greedy decoding):They can be able to make a company that I can get a company .
# 정답:The parts that need to be removed from the production have to be returned to stock before I can remove them from the production BOM .
# =====================================
# epoch 4 iteration 6400/11250 loss 4.0703
# epoch 4 iteration 6800/11250 loss 4.0492
# epoch 4 iteration 7200/11250 loss 4.0570
# epoch 4 iteration 7600/11250 loss 4.0303
# epoch 4 iteration 8000/11250 loss 4.0402
# =====================================
# 입력:할머니는 내가 여기에 있게 한 유일한 이유이며 아무도 내편을 들지 않을때 내옆에 있어준 유일한 사람입니다 .
# 출력(teacher forcing):I family is that way that why me me know able , the same a who the . the . I person of a is the know
# 출력(greedy decoding):The reason why I have a person who is a lot of the best choice .
# 정답:My gran is the only reason to let me be here and the only person to stand by me when no one was there for me .
# =====================================
# epoch 4 iteration 8400/11250 loss 4.0464
# epoch 4 iteration 8800/11250 loss 4.0479
# epoch 4 iteration 9200/11250 loss 4.0631
# epoch 4 iteration 9600/11250 loss 4.0522
# epoch 4 iteration 10000/11250 loss 4.0212
# =====================================
# 입력:어떻게 보면 나는 지금까지도 텔레비전을 보고 나가서 노는 것보다 책 읽는 게 더 좋은 이유가 이것 때문에 일 수도 있습니다 .
# 출력(teacher forcing):I the good , I time be a I can good to a to see the . I the .
# 출력(greedy decoding):I 'm going to learn a good job in the class , but I can I think of the class
# 정답:In a way , this may be why I still prefer reading books to watching television and playing outside .
# =====================================
# epoch 4 iteration 10400/11250 loss 4.0497
# epoch 4 iteration 10800/11250 loss 4.0360
# epoch 4 iteration 11200/11250 loss 4.0247
# epoch 5 iteration 400/11250 loss 3.9497
# epoch 5 iteration 800/11250 loss 3.9668
# epoch 5 iteration 1200/11250 loss 3.9560
# epoch 5 iteration 1600/11250 loss 3.9417
# epoch 5 iteration 2000/11250 loss 3.9475
# =====================================
# 입력:한국에서 발급된 신용 카드 및 한국 핸드폰 결제 , 계좌 이체 등의 결제 수단을 이용하실 경우 선택하세요 .
# 출력(teacher forcing):If check the the are to the the reservation card , to Korea , the the for the products phone . and . to and .
# 출력(greedy decoding):The reservation of the product is the reservation for the payment of the product , and the reservation and the product is a company 's product
# 정답:Please check if you want to use a credit card issued in Korea , or pay with Korean mobile phone , account transfer , etc .
# =====================================
# epoch 5 iteration 2400/11250 loss 3.9442
# epoch 5 iteration 2800/11250 loss 3.9577
# epoch 5 iteration 3200/11250 loss 3.9488
# epoch 5 iteration 3600/11250 loss 3.9626
# epoch 5 iteration 4000/11250 loss 3.9492
# =====================================
# 입력:아카리는 타카키를 어린 시절의 좋은 추억으로만 생각하고 있으며 , 다른 사람과 약혼을 한 상태이며 결혼을 코앞에 둔 상태입니다 .
# 출력(teacher forcing):The of of , is a good person , the and . and is a . the life . and the lives a the be a .
# 출력(greedy decoding):The person who are a good job for the other people who are in the other people who are in the world .
# 정답:Akari thinks Takaki only as a good memory of her childhood , she is engaged to another person , and she is about to get married .
# =====================================
# epoch 5 iteration 4400/11250 loss 3.9429
# epoch 5 iteration 4800/11250 loss 3.9625
# epoch 5 iteration 5200/11250 loss 3.9511
# epoch 5 iteration 5600/11250 loss 3.9685
# epoch 5 iteration 6000/11250 loss 3.9463
# =====================================
# 입력:뇌는 잠을 자는 동안 정보를 저장한다고 하는데 적당한 낮잠은 뇌파를 활발하게 해주기 때문에 기억력 향상에 큰 도움을 줍니다 .
# 출력(teacher forcing):I is a to the best and and information of you have and so I positive result . to help the . a . a . .
# 출력(greedy decoding):I am sure to make a lot of the person who are a big help of the future .
# 정답:It is known that our brain stores the information when we sleep , and a moderate nap helps to enhance memory as it stimulates brain waves .
# =====================================
# epoch 5 iteration 6400/11250 loss 3.9486
# epoch 5 iteration 6800/11250 loss 3.9424
# epoch 5 iteration 7200/11250 loss 3.9668
# epoch 5 iteration 7600/11250 loss 3.9602
# epoch 5 iteration 8000/11250 loss 3.9775
# =====================================
# 입력:반면 하위 50 % 가 가지고 있는 자산은 고작 전체의 2 % 의 수준밖에 미치지 않습니다 .
# 출력(teacher forcing):The the , the market , the % of % of in to % of the total .
# 출력(greedy decoding):The total of the company is in the center of the total of the United States .
# 정답:In contrast , the assets of the bottom 50 % only reached 2 % of the whole .
# =====================================
# epoch 5 iteration 8400/11250 loss 3.9550
# epoch 5 iteration 8800/11250 loss 3.9778
# epoch 5 iteration 9200/11250 loss 3.9482
# epoch 5 iteration 9600/11250 loss 3.9410
# epoch 5 iteration 10000/11250 loss 3.9597
# =====================================
# 입력:Ups 배송은 길이가 15m가 넘으면 우리는 무게로 배송비를 책정하지 않고 가로 x 세로 x 높이를 합해서 계산해요 .
# 출력(teacher forcing):We you shipment , is the the of , we have n't need the price of of the of we the the the price of the and the .
# 출력(greedy decoding):We have to use the price and the factory and the product and the total of the shipping fee of the product and the price of the factory and
# 정답:If the UPS delivery is over 15m long , we do not set the shipping cost by weight but calculate by adding the height of x by x .
# =====================================
# epoch 5 iteration 10400/11250 loss 3.9571
# epoch 5 iteration 10800/11250 loss 3.9666
# epoch 5 iteration 11200/11250 loss 3.9517
# epoch 6 iteration 400/11250 loss 3.8444
# epoch 6 iteration 800/11250 loss 3.8703
# epoch 6 iteration 1200/11250 loss 3.8595
# epoch 6 iteration 1600/11250 loss 3.8412
# epoch 6 iteration 2000/11250 loss 3.8589
# =====================================
# 입력:아래 아이템의 금 함량이 그램으로 표시하는지 혹은 퍼센트로 표시하는지 당신은 확인 할 수 있나요 ?
# 출력(teacher forcing):Can you check the the product and below the product below ? the ? the ? the of
# 출력(greedy decoding):If the machine , you can not be able to the price of the product .
# 정답:Can you check whether the gold content of the items below is expressed in gram or percent ?
# =====================================
# epoch 6 iteration 2400/11250 loss 3.8818
# epoch 6 iteration 2800/11250 loss 3.8853
# epoch 6 iteration 3200/11250 loss 3.8545
# epoch 6 iteration 3600/11250 loss 3.8906
# epoch 6 iteration 4000/11250 loss 3.8694
# =====================================
# 입력:금오산 아래 낙동강이 아름다운 이곳 구미시 승마장은 전국 최초의 공식 승마길로 국내 유일의 크로스컨트리 경기장입니다 .
# 출력(teacher forcing):The is is , the and the first of and the the for the first University , and the most of of of . is the as the most
# 출력(greedy decoding):The first photo of the most of the first floor of the most of the last year of the world is the most of the most beautiful of the first .
# 정답:This horseriding course in Gumi under the Kumho Mountain which is famous for the beautiful Nakdong River is the only cross country stadium that is known as the first
# =====================================
# epoch 6 iteration 4400/11250 loss 3.8739
# epoch 6 iteration 4800/11250 loss 3.8770
# epoch 6 iteration 5200/11250 loss 3.8781
# epoch 6 iteration 5600/11250 loss 3.8819
# epoch 6 iteration 6000/11250 loss 3.8698
# =====================================
# 입력:거기에 담긴 의미들은 이산가족들의 염원이 전부 담겨있었고 , 많은 사람은 감동하게 해 한동안 큰 이슈가 되었어요 .
# 출력(teacher forcing):It result of in the , always time to the future of and and I times are always by the 's a lot . . a lot .
# 출력(greedy decoding):It 's a lot of people who was a lot of the same time .
# 정답:The meanings contained in them are the wishes of the separated families , and many people were impressed and it was a huge issue for a while .
# =====================================
# epoch 6 iteration 6400/11250 loss 3.8913
# epoch 6 iteration 6800/11250 loss 3.8823
# epoch 6 iteration 7200/11250 loss 3.8699
# epoch 6 iteration 7600/11250 loss 3.8888
# epoch 6 iteration 8000/11250 loss 3.8906
# =====================================
# 입력:네가 날 안 좋아해도 겸허히 받아들이겠지만 , 너와 내가 생각이 다르다고 , 스타일이 다르다고 내 사랑을 깎아내리지 마요 .
# 출력(teacher forcing):I did not that if you do n't know you , you n't like well your me own , I do you . love are not .
# 출력(greedy decoding):I 'm not a person who is to do n't think you and not have a person .
# 정답:I will understand even if you do n't like me but do n't look down upon my love because we think differently and we are different .
# =====================================
# epoch 6 iteration 8400/11250 loss 3.8755
# epoch 6 iteration 8800/11250 loss 3.8791
# epoch 6 iteration 9200/11250 loss 3.8931
# epoch 6 iteration 9600/11250 loss 3.8624
# epoch 6 iteration 10000/11250 loss 3.8574
# =====================================
# 입력:그러므로 , 우리는 당신을 최고의 서비스를 제공하는 우리 은행에 초대하길 원합니다 .
# 출력(teacher forcing):Therefore , we want to make you to the money and we we your best . .
# 출력(greedy decoding):Therefore , we want to introduce you to the best to you .
# 정답:Therefore , we want to invite you to our bank , which provides the best service .
# =====================================
# epoch 6 iteration 10400/11250 loss 3.8947
# epoch 6 iteration 10800/11250 loss 3.8787
# epoch 6 iteration 11200/11250 loss 3.8859
# epoch 7 iteration 400/11250 loss 3.7689
# epoch 7 iteration 800/11250 loss 3.7842
# epoch 7 iteration 1200/11250 loss 3.7905
# epoch 7 iteration 1600/11250 loss 3.7951
# epoch 7 iteration 2000/11250 loss 3.8098
# =====================================
# 입력:당신은 그동안의 경험을 바탕으로 더 이른 시간안에 클리어하기 위한 새로운 모험에 도전해 보시는 건 어떨까요 ?
# 출력(teacher forcing):What on the experience , the you you be have to new job ? be . ? ?
# 출력(greedy decoding):What is the new experience of the new year ?
# 정답:Based on your experience , why do n't you try a new adventure to clear up sooner ?
# =====================================
# epoch 7 iteration 2400/11250 loss 3.7953
# epoch 7 iteration 2800/11250 loss 3.8060
# epoch 7 iteration 3200/11250 loss 3.8031
# epoch 7 iteration 3600/11250 loss 3.8145
# epoch 7 iteration 4000/11250 loss 3.8073
# =====================================
# 입력:십오 년 후쯤 나는 꿈도 이루고 결혼도 해서 행복한 가정도 꾸리고 많은 나라를 여행 다녔으면 좋겠어요 .
# 출력(teacher forcing):I I years , I wish like to live my family of I a to I a lot to and and I to live people .
# 출력(greedy decoding):I want to be a lot of people who to see the family and a new country .
# 정답:After 15 years , I would like to achieve my dream , get married , have a happy family , and travel to many countries .
# =====================================
# epoch 7 iteration 4400/11250 loss 3.7850
# epoch 7 iteration 4800/11250 loss 3.7985
# epoch 7 iteration 5200/11250 loss 3.7960
# epoch 7 iteration 5600/11250 loss 3.7946
# epoch 7 iteration 6000/11250 loss 3.7990
# =====================================
# 입력:내가 제안하는 첫 번째 해결책은 제한된 시간 동안 스마트폰 사용을 방해하는 앱을 설치하는 것입니다 .
# 출력(teacher forcing):I first reason is can I the use the for I be the by of the month time .
# 출력(greedy decoding):The first time of the first time I can not be able to use the process of the first
# 정답:The first solution I suggest is to install apps that will prevent smartphone usage for a limited time .
# =====================================
# epoch 7 iteration 6400/11250 loss 3.8018
# epoch 7 iteration 6800/11250 loss 3.8080
# epoch 7 iteration 7200/11250 loss 3.8096
# epoch 7 iteration 7600/11250 loss 3.7813
# epoch 7 iteration 8000/11250 loss 3.8247
# =====================================
# 입력:북미 콘텐츠에 강점을 갖춘 푸드가 함께 하면 더 큰 기회를 만들어 나갈 수 있을 거예요 .
# 출력(teacher forcing):It can a to be a lot experience to and the and own and the . the the .
# 출력(greedy decoding):The research is more than the importance of the future and the future .
# 정답:We are expecting to make a bigger opportunity together with Food 's strength in contents in Northern America .
# =====================================
# epoch 7 iteration 8400/11250 loss 3.8364
# epoch 7 iteration 8800/11250 loss 3.8391
# epoch 7 iteration 9200/11250 loss 3.8116
# epoch 7 iteration 9600/11250 loss 3.8311
# epoch 7 iteration 10000/11250 loss 3.8217
# =====================================
# 입력:교실에 앉아서 수업을 듣는 것보다 야외에서 직접 보거나 활동을 통해서 수업을 듣는 것을 더 좋아해요 .
# 출력(teacher forcing):I like watching than a to the the the who the a . a the in the class . I to . the class .
# 출력(greedy decoding):I am watching the class , and I like the class of the class .
# 정답:They enjoy more having classed by seeing in person and doing activities than by sitting on a chair and listening lessons in a classroom .
# =====================================
# epoch 7 iteration 10400/11250 loss 3.8145
# epoch 7 iteration 10800/11250 loss 3.8212
# epoch 7 iteration 11200/11250 loss 3.8290
# epoch 8 iteration 400/11250 loss 3.7388
# epoch 8 iteration 800/11250 loss 3.7056
# epoch 8 iteration 1200/11250 loss 3.7259
# epoch 8 iteration 1600/11250 loss 3.7471
# epoch 8 iteration 2000/11250 loss 3.7363
# =====================================
# 입력:수 많은 콘텐츠들 중에서 당신의 콘텐츠를 상위에 노출하기 위해서는 투표를 해야 합니다 .
# 출력(teacher forcing):We is the you to new , to the following of the following of
# 출력(greedy decoding):We need to change the following the following and the following and the following
# 정답:Upvoting is what helps your content get to the top of the heap .
# =====================================
# epoch 8 iteration 2400/11250 loss 3.7444
# epoch 8 iteration 2800/11250 loss 3.7289
# epoch 8 iteration 3200/11250 loss 3.7524
# epoch 8 iteration 3600/11250 loss 3.7592
# epoch 8 iteration 4000/11250 loss 3.7490
# =====================================
# 입력:네 말은 원산지 증명서에 ' A'라는 문구를 추가해주고 인보이스와 BL에 발송인을 ' B ' 로 바꿔 달라는 거지 ?
# 출력(teacher forcing):Your can that the the original , the , and the below of the of the you shipment ' the '' the '' ' the the '' '
# 출력(greedy decoding):The information of the product is already received and the original name of the original file ' ' ?
# 정답:You mean to add the phrase `` A '' to the certificate of origin and ask the invoice and BL to change SHIPPER to `` B '' ?
# =====================================
# epoch 8 iteration 4400/11250 loss 3.7568
# epoch 8 iteration 4800/11250 loss 3.7406
# epoch 8 iteration 5200/11250 loss 3.7663
# epoch 8 iteration 5600/11250 loss 3.7337
# epoch 8 iteration 6000/11250 loss 3.7504
# =====================================
# 입력:이러한 의미에서 마약 전쟁은 전쟁이 아니고 , 문자 그대로의 전쟁은 이전에 끝이 났다는 것을 의미해요 .
# 출력(teacher forcing):The the fact , the world , , not to , the was not little of reality . meaning . the . .
# 출력(greedy decoding):This is not a word , but the world , but it 's not the world .
# 정답:In this sense , the drug war is not war but it 's a sense of literal 's war before it ends .
# =====================================
# epoch 8 iteration 6400/11250 loss 3.7454
# epoch 8 iteration 6800/11250 loss 3.7171
# epoch 8 iteration 7200/11250 loss 3.7631
# epoch 8 iteration 7600/11250 loss 3.7677
# epoch 8 iteration 8000/11250 loss 3.7328
# =====================================
# 입력:많은 대회가 개최되고 또 많은 여성이 출전하고 있지만 우리는 이것이 과연 옳은가에 대해 생각해 볼 필요가 있습니다 .
# 출력(teacher forcing):Many are many people and I people are a with and we are to see of the it is a .
# 출력(greedy decoding):I think we are a lot of people who are in the middle of music and I am going to see
# 정답:There are many contests and many women are competing , but we need to think about whether this is right .
# =====================================
# epoch 8 iteration 8400/11250 loss 3.7643
# epoch 8 iteration 8800/11250 loss 3.7571
# epoch 8 iteration 9200/11250 loss 3.7376
# epoch 8 iteration 9600/11250 loss 3.7548
# epoch 8 iteration 10000/11250 loss 3.7493
# =====================================
# 입력:난민 등은 정세에 따라 형을 면제받을 수도 있으니 관련 조항을 세심하게 살펴보기 바랍니다 .
# 출력(teacher forcing):If , the can be changed from the , the with the end . so it can be . the end to .
# 출력(greedy decoding):I can not be able to the first time , the government who the work .
# 정답:Refugees and others can be exempted from sentence in accordance with the situation , so you should carefully check the related articles .
# =====================================
# epoch 8 iteration 10400/11250 loss 3.7591
# epoch 8 iteration 10800/11250 loss 3.7805
# epoch 8 iteration 11200/11250 loss 3.7552
# epoch 9 iteration 400/11250 loss 3.6622
# epoch 9 iteration 800/11250 loss 3.6639
# epoch 9 iteration 1200/11250 loss 3.6764
# epoch 9 iteration 1600/11250 loss 3.6676
# epoch 9 iteration 2000/11250 loss 3.7009
# =====================================
# 입력:이것은 가늘게 채 썬 메밀묵 , 잘게 썬 배추김치에 김 가루 , 갖은양념을 넣은 다음 찬 육수를 부은 냉국입니다 .
# 출력(teacher forcing):This is a red cream , the mukbang , , the pepper of and , and , , and the and ,
# 출력(greedy decoding):This is a red pepper paste , and the sauce , and cheese .
# 정답:This is a cold soup with buckwheat jelly cut into small pieces , Kimchi , seaweed flakes , and cold stock .
# =====================================
# epoch 9 iteration 2400/11250 loss 3.6931
# epoch 9 iteration 2800/11250 loss 3.6796
# epoch 9 iteration 3200/11250 loss 3.6680
# epoch 9 iteration 3600/11250 loss 3.6892
# epoch 9 iteration 4000/11250 loss 3.6763
# =====================================
# 입력:당신의 평가에 대하여 먼저 감사드리고 빨리 연락을 드리지 못하여 죄송합니다 .
# 출력(teacher forcing):Thank 'm it request and I for am n't know you . .
# 출력(greedy decoding):I 'm sorry , but I 'm sorry to help you .
# 정답:I appreciate your evaluation and apologize I did n't contact you promptly .
# =====================================
# epoch 9 iteration 4400/11250 loss 3.6774
# epoch 9 iteration 4800/11250 loss 3.6995
# epoch 9 iteration 5200/11250 loss 3.6803
# epoch 9 iteration 5600/11250 loss 3.7047
# epoch 9 iteration 6000/11250 loss 3.7355
# =====================================
# 입력:7월 25일 , ABC는 8월 15일에 열릴 댄의 50번째 생일 파티에 맞추기로 합의했어요 . 같은 날 , ABC의 급식 담당자는 육류 공급 회사의 사장인 베티에게 전화를 걸었습니다 .
# 출력(teacher forcing):The the , , the , to be to the , s the Day , in the been in July 20th years
# 출력(greedy decoding):The first time of the first day of the last year , and the company is the last night .
# 정답:On July 25 , ABC agreed to cater to Dan ’ s 50th birthday party to be held on August 15 . That same day , ABC ’ s
# =====================================
# epoch 9 iteration 6400/11250 loss 3.7012
# epoch 9 iteration 6800/11250 loss 3.6912
# epoch 9 iteration 7200/11250 loss 3.7173
# epoch 9 iteration 7600/11250 loss 3.7268
# epoch 9 iteration 8000/11250 loss 3.7083
# =====================================
# 입력:억압된 무의식은 어떤 식으로든 분출되는데 , 무심코 나온 말실수나 흔히 꾸는 꿈 등이 대표적 예입니다 .
# 출력(teacher forcing):The is , , , the , the fact , and the , , the , to and lot of and .
# 출력(greedy decoding):The reason is a story of the fact that the world , and the most .
# 정답:This suppressed unconsciousness come into sight in any way , and common examples are improper talking , a dream , etc .
# =====================================
# epoch 9 iteration 8400/11250 loss 3.7040
# epoch 9 iteration 8800/11250 loss 3.6954
# epoch 9 iteration 9200/11250 loss 3.6962
# epoch 9 iteration 9600/11250 loss 3.7122
# epoch 9 iteration 10000/11250 loss 3.7056
# =====================================
# 입력:그녀의 무역상들은 동쪽과 서쪽으로 이동하며 , 모든 땅과 바다로 판로를 개척했어요 .
# 출력(teacher forcing):Her own , a to the the the and all own to the year . the year .
# 출력(greedy decoding):Her house is a big place where the city is a small of the city .
# 정답:Her traders were moving East and West , finding their way into every land and every sea .
# =====================================
# epoch 9 iteration 10400/11250 loss 3.6900
# epoch 9 iteration 10800/11250 loss 3.7043
# epoch 9 iteration 11200/11250 loss 3.7188
# epoch 10 iteration 400/11250 loss 3.6007
# epoch 10 iteration 800/11250 loss 3.6342
# epoch 10 iteration 1200/11250 loss 3.6164
# epoch 10 iteration 1600/11250 loss 3.6360
# epoch 10 iteration 2000/11250 loss 3.6461
# =====================================
# 입력:이러한 IMF의 원인을 알게 되고 , 스트레스 테스트의 골자도 알게 된 후 나는 문득 궁금해지는 것이 있었어 .
# 출력(teacher forcing):I the the fact of this , I same I the fact of , I was been of .
# 출력(greedy decoding):I was able to know how the most of the day I was not now .
# 정답:After learning the cause of IMF and the essentials of the Stress Test , I had one question .
# =====================================
# epoch 10 iteration 2400/11250 loss 3.6259
# epoch 10 iteration 2800/11250 loss 3.6420
# epoch 10 iteration 3200/11250 loss 3.6286
# epoch 10 iteration 3600/11250 loss 3.6510
# epoch 10 iteration 4000/11250 loss 3.6367
# =====================================
# 입력:현재는 여기에 많은 카페와 편의시설 , 편리한 교통시설이 있어 저는 만족을 느끼고 있습니다 .
# 출력(teacher forcing):Recently , I is a cases and the in and to is are it 'm . with
# 출력(greedy decoding):I 'm currently having a lot of days , but I am a lot of health .
# 정답:Currently , there are many cafes and facilities , convenient transportation facilities so I feel satisfied .
# =====================================
# epoch 10 iteration 4400/11250 loss 3.6629
# epoch 10 iteration 4800/11250 loss 3.6522
# epoch 10 iteration 5200/11250 loss 3.6617
# epoch 10 iteration 5600/11250 loss 3.6535
# epoch 10 iteration 6000/11250 loss 3.6504
# =====================================
# 입력:우리는 해당 건의 견적을 A에서 승인했는데 , A의 고객인 B가 직접 당신에게 비용 지급을 할 예정이라고 합니다 .
# 출력(teacher forcing):We have to the contract of the contract and the company 's and 's and be the the .
# 출력(greedy decoding):We are going to the contract with the contract , and the contract of the following fee .
# 정답:We have approved the quote on A , and our customer , B , will pay you directly .
# =====================================
# epoch 10 iteration 6400/11250 loss 3.6451
# epoch 10 iteration 6800/11250 loss 3.6335
# epoch 10 iteration 7200/11250 loss 3.6418
# epoch 10 iteration 7600/11250 loss 3.6658
# epoch 10 iteration 8000/11250 loss 3.6558
# =====================================
# 입력:방학 동안 공부하려고 책을 사긴 했지만 일학년 아니면 방학을 즐길 수 없을 것 같아서 과감히 공부를 접었어 .
# 출력(teacher forcing):I was a books because learn a the vacation , but I can to learn learn I have of movies time . the . . concert time . study
# 출력(greedy decoding):I could not learn how to watch the class , but I would like to see the movie .
# 정답:I bought some books to study during the holiday , but I decided not to because I thought the first year of college is the last chance to enjoy
# =====================================
# epoch 10 iteration 8400/11250 loss 3.6591
# epoch 10 iteration 8800/11250 loss 3.6690
# epoch 10 iteration 9200/11250 loss 3.6442
# epoch 10 iteration 9600/11250 loss 3.6587
# epoch 10 iteration 10000/11250 loss 3.6553
# =====================================
# 입력:김에 밥과 닭강정 , 계란 , 당근 , 시금치 등 여러 가지 재료를 넣고 말아 싼 음식 .
# 출력(teacher forcing):The a of food , , and and , eat sauce , and , and and eat . the sauce . vegetables . .
# 출력(greedy decoding):Do n't sell meat and eat meat and eat , and eat meat and vegetables .
# 정답:Put kinds of ingredients like rice , sweet and sour chicken , egg , carrot and spinach on the weed and roll it .
# =====================================
# epoch 10 iteration 10400/11250 loss 3.6512
# epoch 10 iteration 10800/11250 loss 3.6591
# epoch 10 iteration 11200/11250 loss 3.6636

# %%
#결과값 출력
model.eval()
for idx, batch in enumerate(train_loader):
    x, y, x_len, y_len = batch
    x = x.cuda()
    y = y.cuda()
    pred = model.greedy_decoding(x)

    for i in range(pred.shape[0]):
        pred_indices = pred[i].data.cpu().tolist()
        input_indices = x[i].data.cpu().tolist()
        label_indices = y[i].data.cpu().tolist()

        if 2 in pred_indices:
            pred_len = pred_indices.index(2)
        else:
            pred_len = 128

        if 2 in input_indices:
            input_len = input_indices.index(2)
        else:
            input_len = 128
        
        if 2 in label_indices:
            label_len = label_indices.index(2)
        else:
            label_len = 128
        
        pred_words = [english_id2word[idx] for i,idx in enumerate(pred_indices) if i <= pred_len]
        input_words = [korean_id2word[idx] for i,idx in enumerate(input_indices) if i <= input_len]
        label_words = [english_id2word[idx] for i,idx in enumerate(label_indices) if i <= label_len]
        if pred_len>1:
            print('===================')
            print('입력:{}'.format(' '.join(input_words)))
            print('출력(greedy decoding):{}'.format(' '.join(pred_words)))
            print('답안:{}'.format(' '.join(label_words)))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# ===================
# 입력:<s> 당신의 수당은 총 3,000불입니다 . </s>
# 출력(greedy decoding):I have to know the total of the total of the total of the hotel . </s>
# 답안:<s> Your payment is a total of 3,000 dollars . </s>
# ===================
# 입력:<s> 너 여행 때문에 피곤했나봐 . </s>
# 출력(greedy decoding):I have to know if you have to know the trip . </s>
# 답안:<s> You seemed to be tired from traveling . </s>
# ===================
# 입력:<s> 각 도면은 그 앞에 오는 도면과 그리고 그 뒤에 오는 도면과 약간 다를 뿐이에요 . </s>
# 출력(greedy decoding):Each number is the screen , and the same time of the screen . </s>
# 답안:<s> Each drawing differ only slightly from the drawing that comes before it and the one that comes after it . </s>
# ===================
# 입력:<s> 베지마이트는 야채에서 추출한 즙과 소금 , 이스트를 추출물로 만든 잼이라고 보면 됩니다 . </s>
# 출력(greedy decoding):If the water , it is the water , it is the natural cream of the water . </s>
# 답안:<s> Vegemite is a jam which is made with vegetable extracts , salt , and yeast . </s>
# ===================
# 입력:<s> 지난번에 Park 모델 관련 문의드렸었는데 , 현재에도 가지고 계신 원숭이 모델이 없으신지요 ? </s>
# 출력(greedy decoding):I have received the design of the product last year , but I have a model ? </s>
# 답안:<s> Last time , I inquired regarding the Park model , but do n't you still have the monkey model ? </s>
# ===================
# 입력:<s> 나는 지금 출근 중인데 출근하면 이걸 다른 팀원들과 공유할 거예요 . </s>
# 출력(greedy decoding):I have to know the meeting with you now . </s>
# 답안:<s> I am on my way to work , and when I get there , ill share it with other team members . </s>
# ===================
# 입력:<s> 그리고 그중 어떤 것도 당신과 함께할 것은 없을 것입니다 . </s>
# 출력(greedy decoding):And I know what I have to know what I have to do . </s>
# 답안:<s> And none of it will have anything to do with you . </s>
# ===================
# 입력:<s> 허니문 여행이니 룸 컨디션과 서비스에 특별히 신경 써 주세요 . </s>
# 출력(greedy decoding):I know the room , please contact the room and get a lot of money . </s>
# 답안:<s> It ’ s our honeymoon , so please take extra care to room condition and service . </s>
# ===================
# 입력:<s> 우리는 국제적 인증을 가진 후보들에게는 이 프로그램을 제공하지 않습니다 . </s>
# 출력(greedy decoding):We have to provide this program to provide the program . </s>
# 답안:<s> We are not offering this program to candidates with an international qualification . </s>
# ===================
# 입력:<s> 머리의 굴곡을 맞추어 안 와이 도선이 직각이 되도록 하세요 . </s>
# 출력(greedy decoding):If you know the body , you need to know the power . </s>
# 답안:<s> Adjust the flexion of the head so that the orbit metal line is perpendicular . </s>
# ===================
# 입력:<s> 우리는 치킨에 의해 치킨을 위한 삶을 살고 있습니다 . </s>
# 출력(greedy decoding):We have to live in the world . </s>
# 답안:<s> We live a life by chicken and for chicken . </s>
# ===================
# 입력:<s> 하지만 오늘날 사람들은 휴대전화와 RFID 배지를 휴대하고 다닌다 . </s>
# 출력(greedy decoding):But there are the way to use the body of the body . </s>
# 답안:<s> Today , however , people carry cell phones and wear RFID badges . </s>
# ===================
# 입력:<s> 내 뜨거운 입술이 너의 부드러운 입술에 닿기를 원해요 . </s>
# 출력(greedy decoding):I know the blue color of your face . </s>
# 답안:<s> I want to touch your smooth lips with my hot lips . </s>
# ===================
# 입력:<s> 우리는 토마토로 많은 음식을 만들 수 있어요 . </s>
# 출력(greedy decoding):We need to know many food . </s>
# 답안:<s> We can make a variety of foods with tomatoes . </s>
# ===================
# 입력:<s> 당신도 그와 같이 가야 할 것 같아요 . </s>
# 출력(greedy decoding):I know you have to go to him . </s>
# 답안:<s> I think you should go with him . </s>
# ===================
# 입력:<s> 그들은 자신의 삶을 포기하고 게임을 선택했어요 . </s>
# 출력(greedy decoding):They know that they have to get a game . </s>
# 답안:<s> They gave up their lives and chose to play games . </s>
# ===================
# 입력:<s> 나는 모든 일에 3번까지 허용된다고 생각해요 . </s>
# 출력(greedy decoding):I know all the work is the job . </s>
# 답안:<s> I think that everything is allowed up to three times . </s>
# ===================
# 입력:<s> 그 물건들은 서로 엉겨 붙어 있었다 . </s>
# 출력(greedy decoding):I have been to know that product . </s>
# 답안:<s> The goods were tangled . </s>
# ===================
# 입력:<s> 전화하면 말이 통하지 않아서 안 해 . </s>
# 출력(greedy decoding):I have to know what I have to know . </s>
# 답안:<s> I do n't call because we do n't understand each other . </s>
# ===================
# 입력:<s> 부상으로 인해 느꼈을 통증에 정말 죄송해요 . </s>
# 출력(greedy decoding):I know that I have to know the end of the day . </s>
# 답안:<s> So sorry for all the pains from the injuries . </s>
# ===================
# 입력:<s> 이 동물을 주인공으로 한 영화도 있어요 . </s>
# 출력(greedy decoding):I have to know this food . </s>
# 답안:<s> There is also a movie featuring this animal . </s>
# ===================
# 입력:<s> 새로운 사업 준비는 잘 되어가고 있습니까 ? </s>
# 출력(greedy decoding):I have to know how many new business is ? </s>
# 답안:<s> How are the arrangements for your new business going ? </s>
# ===================
# 입력:<s> 당신이 좋아해 주어서 저도 기쁘네요 . </s>
# 출력(greedy decoding):I know you know you are now . </s>
# 답안:<s> I am happy that you like it . </s>
# ===================
# 입력:<s> 그는 2월에 중학교를 졸업할 예정입니다 . </s>
# 출력(greedy decoding):He said he was going to go to the February . </s>
# 답안:<s> He will graduate the middle school in February . </s>
# ===================
# 입력:<s> 난 세상이 변화는 것을 지켜보았어요 . </s>
# 출력(greedy decoding):I know the world , I need to know the world . </s>
# 답안:<s> I 've observed the world change . </s>
# ===================
# 입력:<s> 우리는 도전하는 정신으로 목표를 정했어요 . </s>
# 출력(greedy decoding):We have to know the goal of the goal of the goal . </s>
# 답안:<s> We set our goals with challenging minds . </s>
# ===================
# 입력:<s> EMAPI로 구현할 방법은 정말 없나요 ? </s>
# 출력(greedy decoding):I know the way to know the way to the way ? </s>
# 답안:<s> Is there really no way to implement it with EMAPI ? </s>
# ===================
# 입력:<s> 지금 혼자 있고 싶어서 그렇습니다 . </s>
# 출력(greedy decoding):I have to know what I have to know . </s>
# 답안:<s> It 's because I want to be alone right now . </s>
# ===================
# 입력:<s> 저는 브라질에 간 적이 있어요 . </s>
# 출력(greedy decoding):I have to know the festival of the world . </s>
# 답안:<s> I 've been to Brazil . </s>
# ===================
# 입력:<s> 이쪽 분야에서는 다 그렇죠 . </s>
# 출력(greedy decoding):I have to know this way to be already . </s>
# 답안:<s> It is the same in this business , anyway . </s>
# ===================
# 입력:<s> 다행히도 제 시간에 오셨네요 . </s>
# 출력(greedy decoding):Fortunately , I have been to know the time . </s>
# 답안:<s> You came on time , fortunately . </s>
# ===================
# 입력:<s> 제가 여기선 확인하기 힘드네요 . </s>
# 출력(greedy decoding):I have to know the time I have to know . </s>
# 답안:<s> I am hard to tell from here . </s>
# ===================
# 입력:<s> 신승용은 사탄이나 다름없습니다 . </s>
# 출력(greedy decoding):I have to know the same time . </s>
# 답안:<s> Shin Seung Yong no different than a Satan . </s>
# ===================
# 입력:<s> 결혼하면 기분이 어떤가요 ? </s>
# 출력(greedy decoding):I know what I know what I have to know ? </s>
# 답안:<s> What does it feel like to be married ? </s>
# ===================
# 입력:<s> 환경 보호를 하기 위해서는 길거리에 쓰레기를 버리지 않고 , 플라스틱 제품을 적게 써야 해요 . </s>
# 출력(greedy decoding):If the environment , the water is not to prevent the skin without the skin . </s>
# 답안:<s> To protect our environment , we should not throw away garbage on the streets and should use less plastic products . </s>
# ===================
# 입력:<s> 예쁘게 꾸미는 것을 좋아하기는 하지만 프레지를 다뤄본 것은 처음이라 아주 서툴렀고 힘들었어 . </s>
# 출력(greedy decoding):I have been to be a little because I was not to be happy because it was a little difficult to be a little difficult to be a </s>
# 답안:<s> I like to decorate nicely , but it was hard and awkward because it was my first time dealing with Prezi . </s>
# ===================
# 입력:<s> 태릉국제스케이트장이 2000년 1월 개장하기 전까지만 해도 한국 빙상의 인프라는 원시적인 수준에 머물렀습니다 . </s>
# 출력(greedy decoding):The Korean , the government is the national holiday of the Republic of the Republic of the Republic of the Republic of the Republic of the Republic of January . </s>
# 답안:<s> The skating infrastructure in Korea was rather primeval until Taereung International Skating Rink is opened in January 2000 . </s>
# ===================
# 입력:<s> 내가 생각엔 전부터 항상 알고 싶었던 게 여기 있는 거 같아 . </s>
# 출력(greedy decoding):I know you have to know that I was here . </s>
# 답안:<s> Well , I guess there is one thing I 've always wanted to know . </s>
# ===================
# 입력:<s> 방문자 분석과 채팅 연동이 어떻게 고객 만족도를 향상하는지 안내해 드립니다 . </s>
# 출력(greedy decoding):I know the client who is the client who is the client company who are the client company . </s>
# 답안:<s> We guide how the visitor analysis and chatting interlock enhance customer satisfaction . </s>
# ===================
# 입력:<s> 그들은 기존의 시스템 내에서의 변화가 아니라 시스템 자체를 뜯어고치고자 하였습니다 . </s>
# 출력(greedy decoding):They have been confirmed , but the data of the data of the data of the data . </s>
# 답안:<s> They tried to fix the system completely instead of changing something in an existing condition . </s>
# ===================
# 입력:<s> 학교프로그램과 입학지원서에 대한 정보는 어떻게 더 얻을 수 있나요 ? </s>
# 출력(greedy decoding):How can you know the information of the information of the information ? </s>
# 답안:<s> How can I get further information about the school 's programs and obtain an enrollment application ? </s>
# ===================
# 입력:<s> 반면에 성숙한 사람의 특징은 그가 살고 싶어 한다는 것이에요 . </s>
# 출력(greedy decoding):We know that he is the characteristics of the person who is the person who is in the world . </s>
# 답안:<s> While the mark of a mature man is that he wants to live . </s>
# ===================
# 입력:<s> 문의를 좀 하고 싶은데 , 연락처를 알 수 있을까요 ? </s>
# 출력(greedy decoding):I know you know if you know the phone number , I have to know ? </s>
# 답안:<s> I 'd like to make some inquiries , could I please get some contact info ? </s>
# ===================
# 입력:<s> 귀사의 고체물감 중 CE 검사를 받은 제품이 있나요 ? </s>
# 출력(greedy decoding):In the product , the product is the product of the product of the product ? </s>
# 답안:<s> Is there CE tested product in your company 's solid paints ? </s>
# ===================
# 입력:<s> 교회의 성스러움은 동서 축선 상의 천정의 빛에 좌우돼요 . </s>
# 출력(greedy decoding):I have to know the main character of the main character of the war . </s>
# 답안:<s> The sanctity of the church depends on the light of the ceiling on the east and west axis . </s>
# ===================
# 입력:<s> 다시 두 건의 예약에 대한 확인서를 요청합니다 . </s>
# 출력(greedy decoding):I know the two documents you need to receive the next time . </s>
# 답안:<s> I request for the confirmation of two reservations again . </s>
# ===================
# 입력:<s> 혹시 이 절차에 대해서 아시는 분 있나요 ? </s>
# 출력(greedy decoding):What is there is the document of this case ? </s>
# 답안:<s> Is there anyone who know about this procedure ? </s>
# ===================
# 입력:<s> 당신이 매우 힘든 일을 겪고 있다고 들었습니다 . </s>
# 출력(greedy decoding):I know you have to do hard to do it . </s>
# 답안:<s> I heard you are experiencing a Gordian Knot . </s>
# ===================
# 입력:<s> 그래서 좋은 기술이 있더라도 사업을 시작하기가 어렵습니다 . </s>
# 출력(greedy decoding):So I have to know how many things are working in the business . </s>
# 답안:<s> So it is hard to start a business even though we have good technology . </s>
# ===================
# 입력:<s> 사람들이 할 일이 없어져서 불행해 질 것입니다 . </s>
# 출력(greedy decoding):I have to know how many things I have to do . </s>
# 답안:<s> People will become unhappy because they have time on their hands . </s>
# ===================
# 입력:<s> 우리는 업체에 따로 계약서를 받을 예정입니다 . </s>
# 출력(greedy decoding):We have to know the company in the company . </s>
# 답안:<s> We plan to receive the contract from an enterprise separately . </s>
# ===================
# 입력:<s> 저만의 엔터테인먼트를 만드는 게 제 목표예요 . </s>
# 출력(greedy decoding):I know my favorite language is the most . </s>
# 답안:<s> My goal is to make my own entertainment company . </s>
# ===================
# 입력:<s> 한국의 울산이라는 도시에 있는 거리에서 샀어요 . </s>
# 출력(greedy decoding):I have to go to Korea and the city of Korea . </s>
# 답안:<s> I bought at the avenue in the city , Ulsan , in Korea . </s>
# ===================
# 입력:<s> 근처에 중고 텐트를 구입할 곳이 없어 . </s>
# 출력(greedy decoding):I have to know the same place where I have to go to the same place . </s>
# 답안:<s> There 's no shops to buy a used tent nearby . </s>
# ===================
# 입력:<s> 교통이 편리하여 여행하시면 참 좋을 것입니다 . </s>
# 출력(greedy decoding):I have to know how to be able to know . </s>
# 답안:<s> It will be nice to travel because of the convenient transportation . </s>
# ===================
# 입력:<s> 저는 당신이 이 바지를 입었으면 좋겠어요 . </s>
# 출력(greedy decoding):I know you have to be able to buy this bag . </s>
# 답안:<s> I 'd like you to wear these pants . </s>
# ===================
# 입력:<s> 그 친구는 귀가 큰 게 특징입니다 . </s>
# 출력(greedy decoding):I know that friend is the biggest way . </s>
# 답안:<s> The friend is characterized by his big ears . </s>
# ===================
# 입력:<s> 나는 매주 월요일에 쉬기로 했어요 . </s>
# 출력(greedy decoding):I have to know the meeting next Monday . </s>
# 답안:<s> I 've decided to get a day off every Monday . </s>
# ===================
# 입력:<s> 당신의 친절에 저는 깊이 감사드립니다 . </s>
# 출력(greedy decoding):I know your kindness , I know your kindness . </s>
# 답안:<s> I deeply thank you for your kindness . </s>
# ===================
# 입력:<s> 그 소식을 듣자마자 그는 뛰어나갔어요 . </s>
# 출력(greedy decoding):I know he was now , and I have been to see the news . </s>
# 답안:<s> The moment he heard the news , he ran out . </s>
# ===================
# 입력:<s> 저는 개인적으로 운동을 정말 좋아합니다 . </s>
# 출력(greedy decoding):I have to know how to exercise . </s>
# 답안:<s> I personally really like sports . </s>
# ===================
# 입력:<s> 제가 깨끗한 것으로 가져도 되나요 ? </s>
# 출력(greedy decoding):I know the water is the day ? </s>
# 답안:<s> May I have a clean one ? </s>
# ===================
# 입력:<s> 저는 그때 누군가와 만나고 있었습니다 . </s>
# 출력(greedy decoding):I have to meet someone when I have to meet . </s>
# 답안:<s> I was with somebody back then . </s>
# ===================
# 입력:<s> 그는 형제가 세 명 있습니다 . </s>
# 출력(greedy decoding):He said he is from the other brother . </s>
# 답안:<s> He has three brothers . </s>
# ===================
# 입력:<s> 6월3일수요일에보자고하셨는데 다음주는 다 휴강인가요 ? </s>
# 출력(greedy decoding):When is the time , I have to go to the end of the end of the time ? </s>
# 답안:<s> You said that you wanted to see me on the 3rd of June on Wednesday , are n't there any classes next week ? </s>
# ===================
# 입력:<s> 이곳은 주차금지 구역입니다 . </s>
# 출력(greedy decoding):I have to know the same time . </s>
# 답안:<s> This is a no-parking zone . </s>
# ===================
# 입력:<s> 저는 기숙사 생활을 하면서 , 1 , 2학기 동안 룸메이트들과 치킨을 2마리씩 11번이나 시켜 먹었습니다 . </s>
# 출력(greedy decoding):I had a fan of the school , and I had a lot of beer and I had a lot of beer . </s>
# 답안:<s> When I was at the dormitory , my roommates and I ordered 2 chickens , 11 times during the first and second semesters . </s>
# ===================
# 입력:<s> 정말 하기 싫었던 일을 때려치우고 집에 와서 샤워하고 거실에 보송보송한 이불을 깔고 누운 순간 . </s>
# 출력(greedy decoding):I heard that I was going to go home and not a shower and wait for a meal . </s>
# 답안:<s> The moment when take a shower , lay down in the sitting inside my fluffy blanket after coming home from abandoning the work I really didn ` t want </s>
# ===================
# 입력:<s> 이전의 연구 결과를 종합해볼 때 , 수산물에 사용되는 항생제의 트렌드는 계속 변화하고 있습니다 . </s>
# 출력(greedy decoding):As the result , the development of the development of the development of the development of the development of the development of the development . </s>
# 답안:<s> Considering previous researches , the trend of antibiotics used for marine products goes through continuous changes . </s>
# ===================
# 입력:<s> 저는 또한 그곳에서 많은 새로운 친구들을 사귀었기 때문에 군대에 있는 것을 즐겼습니다 . </s>
# 출력(greedy decoding):I have been interested in a new trip to the army . </s>
# 답안:<s> I also enjoyed staying in the military because I mad many new friends there . </s>
# ===================
# 입력:<s> 고독이 깊어질수록 세계로부터 더욱 멀어져가고 , 말수가 줄어들수록 몸짓은 부자연스럽게 과장되어갑니다 . </s>
# 출력(greedy decoding):I have to know the world , but I have to be able to be able to be able to be able to be able to be able to be a more than the same time . </s>
# 답안:<s> As solitude is getting deeper , we can be increasingly far away from the world and as becoming quiet , motions become exaggerated . </s>
# ===================
# 입력:<s> 매주 같은 요일마다 주사 맞으러 오는 게 생각보다 쉽지는 않을 거예요 . </s>
# 출력(greedy decoding):I have to go to the same time to the same time . </s>
# 답안:<s> It wo n't be easy to come every week on the same day to get injections . </s>
# ===================
# 입력:<s> 그렇지만 , 당신이 무언가를 정말 잘못했을 때 최선은 조용히 있는 거예요 . </s>
# 출력(greedy decoding):But I know you are so I have to know when you are really like . </s>
# 답안:<s> However , the best thing to do when you 've really done something wrong is to stay quiet . </s>
# ===================
# 입력:<s> 정부에 ‘ 문화예술인 블랙리스트 ' 가 존재한다는 소문은 수년 전부터 떠돌았어 . </s>
# 출력(greedy decoding):The reason of the way of the world was the world of the world . </s>
# 답안:<s> It has been already a few years since the rumor that there exists the blacklist of cultural artists was released . </s>
# ===================
# 입력:<s> 감각 데이터 분석은 센소메트릭스라고 불리는 통계학의 전문 분야를 이용하여 이뤄집니다 . </s>
# 출력(greedy decoding):The data of the data of the data of the data of the data of the data . </s>
# 답안:<s> Sensory data analysis is carried out using a specialized field of statistics called scientometrics . </s>
# ===================
# 입력:<s> 나는 아르바이트를 할 때 계산 담당이라서 숫자를 접할 기회가 많아 . </s>
# 출력(greedy decoding):I have to know the best thing to be able to be a lot of money . </s>
# 답안:<s> I have a lot of experience with numbers because I have a part-time job as a cashier . </s>
# ===================
# 입력:<s> 4월 12일 면접 진행 예정자들의 이력서와 전화 면접 답변을 첨부합니다 . </s>
# 출력(greedy decoding):I have received the report of the document of the first time , and I have received the document . </s>
# 답안:<s> I have attached resumes and phone interviews of interviewees to be interviewed on April 12th . </s>
# ===================
# 입력:<s> 아뇨 , 그는 안에 없지만 , 곧 돌아올 거에요 . </s>
# 출력(greedy decoding):No , he is going to be back to the end of the end . </s>
# 답안:<s> No , he is not in , but I think he will be back at any moment . </s>
# ===================
# 입력:<s> 우리는 어두운 곳에서 서로를 위해 빛날 가장 밝은 빛이야 . </s>
# 출력(greedy decoding):We have to know the most beautiful scenery of each other . </s>
# 답안:<s> We are the brightest light to enlighten each other in the darkest place . </s>
# ===================
# 입력:<s> 내가 상심해 있을 때 마침내 표를 구할 수 있었어 . </s>
# 출력(greedy decoding):I have been to get a ticket when I have to get a ticket . </s>
# 답안:<s> I could get the ticket finally when I was disappointed . </s>
# ===================
# 입력:<s> 한국 남자들은 이런 종류의 요리를 잘하는 여자를 좋아해 . </s>
# 출력(greedy decoding):I know this kind of women , I have to do well . </s>
# 답안:<s> Korean men like a woman good at cooking this sort of thing . </s>
# ===================
# 입력:<s> 아니요 , 뉴질랜드가 일본보다 더 격식을 차리지 않아요 . </s>
# 출력(greedy decoding):No , there are no one of the world . </s>
# 답안:<s> No , New Zealand is more casual than Japan . </s>
# ===================
# 입력:<s> 전 절대 이런 걸 하고 싶지 않은걸요 . </s>
# 출력(greedy decoding):I know that I have to do this way to do it . </s>
# 답안:<s> I never want to do this . </s>
# ===================
# 입력:<s> 나는 여자친구에게 이쁜 옷들을 입게 할 거예요 . </s>
# 출력(greedy decoding):I know I have to go to your girlfriend . </s>
# 답안:<s> I will make my girlfriend wear beautiful clothes . </s>
# ===================
# 입력:<s> 아시안게임 정식 종목이 된 것도 그때부터인가요 ? </s>
# 출력(greedy decoding):I have to know the event of the game in the class ? </s>
# 답안:<s> Is it since then it became a proper event in Asian Games ? </s>
# ===================
# 입력:<s> 제가 그 영화 자체는 좋아하지 않지만요 . </s>
# 출력(greedy decoding):I know that I have to know the movie . </s>
# 답안:<s> I do n't really like the movie itself , though . </s>
# ===================
# 입력:<s> 그녀는 항상 제 책을 공짜로 가져갑니다 . </s>
# 출력(greedy decoding):She said that she is going to be able to get a book . </s>
# 답안:<s> She always takes my books for free . </s>
# ===================
# 입력:<s> 저는 서울에서 안양으로 가는 중이에요 . </s>
# 출력(greedy decoding):I have to know the airport in Seoul . </s>
# 답안:<s> I 'm on my way to Anyang from Seoul . </s>
# ===================
# 입력:<s> 너는 오늘 몇 시에 출국하니 ? </s>
# 출력(greedy decoding):What time is you have to go today ? </s>
# 답안:<s> At what time do you leave the country ? </s>
# ===================
# 입력:<s> 밥 한 그릇 더 드시겠어요 ? </s>
# 출력(greedy decoding):I have to know the water ? </s>
# 답안:<s> How about another bowl of rice ? </s>
# ===================
# 입력:<s> 잔디밭에 들어가면 벌금을 내야 해요 . </s>
# 출력(greedy decoding):I have to know the date of the air conditioner . </s>
# 답안:<s> If you go into a lawn , you will end up paying a fine . </s>
# ===================
# 입력:<s> 제가 좀 지나가게 해 주세요 . </s>
# 출력(greedy decoding):I know the number of the train . </s>
# 답안:<s> Let me go by . </s>
# ===================
# 입력:<s> 세 시간 차이인 줄 알았어요 . </s>
# 출력(greedy decoding):I know the three days ago , I have thought of the time . </s>
# 답안:<s> I thought it was a 3-hour difference . </s>
# ===================
# 입력:<s> 가격 리스트 첨부해 다시 보내드려요 . </s>
# 출력(greedy decoding):I have to know the price of the price of the price . </s>
# 답안:<s> I am resending with the price list attached . </s>
# ===================
# 입력:<s> 나는 공식적으로 인원 증가를 요청합니다 . </s>
# 출력(greedy decoding):I know the government , I need to know the process . </s>
# 답안:<s> I officially request for additional workers . </s>
# ===================
# 입력:<s> 그녀는 미안해 하지도 않았어요 . </s>
# 출력(greedy decoding):I know she was not to know that she was not . </s>
# 답안:<s> She was n't even sorry . </s>
# ===================
# 입력:<s> 냄새도 가시고 곤약이 쫀득해집니다 . </s>
# 출력(greedy decoding):I have to know the air conditioner and get to the air . </s>
# 답안:<s> The smell is gone and the konjac becomes chewy . </s>
# ===================
# 입력:<s> 워크숍에서 주문 요청하였습니다 . </s>
# 출력(greedy decoding):I have checked the order of the order . </s>
# 답안:<s> I requested the order at the workshop . </s>
# ===================
# 입력:<s> 나는 주말에 맘 놓고 12시까지 잔 후 밥 먹으면서 놀다가 과제하고 씻고 자고 그랬어 . </s>
# 출력(greedy decoding):I was going to eat with a meal with a meal with a meal with a meal with a meal . </s>
# 답안:<s> I spent my weekend oversleeping until 12 pm , hanging out , working on the assignment , taking a shower , and falling asleep . </s>
# ===================
# 입력:<s> 첫 번째로 나는 방과 후 수업을 통해서 수업 시간에 부족한 부분을 열심히 공부했습니다 . </s>
# 출력(greedy decoding):First , I have to study English and I studied hard to study English . </s>
# 답안:<s> First , I studied hard in after-school lessons to complement my shortage of learning in regular classes . </s>
# ===================
# 입력:<s> 당신이 산 Mika와 함께 한 쌍의 안구 및 바디가 함께 제공됩니다 . </s>
# 출력(greedy decoding):I have to use the table with you and the table with the table with the table . </s>
# 답안:<s> One pair of eyeball and body will be delivered together with Mika which you have purchased . </s>
# ===================
# 입력:<s> 마음 한켠에 아주 조금이나마 남아있는 사랑의 감각이 그들의 유일한 희망일 뿐입니다 . </s>
# 출력(greedy decoding):I have been to express the meaning of the love of the love . </s>
# 답안:<s> The only hope is the little amount of love left in one 's heart . </s>
# ===================
# 입력:<s> 마지막 이유는 학생이 교복을 입어야 학생들의 행동에 제한이 걸리기 때문입니다 . </s>
# 출력(greedy decoding):The reason I have to do the most of the school who is the school student who is the school . </s>
# 답안:<s> They ca n't do bad things wearing uniform . </s>
# ===================
# 입력:<s> 왜냐하면 , 나는 골프 하면서 건강을 유지하고 싶어서 . </s>
# 출력(greedy decoding):Because I know I have to get a part-time job . </s>
# 답안:<s> Because I want to be healthy by playing golf . </s>
# ===================
# 입력:<s> 물병을 뜨거운 물에 담근 후 뚜껑을 열어 주세요 . </s>
# 출력(greedy decoding):If you have been to the water , please check the water . </s>
# 답안:<s> Put some hot water in the water bottle , then open the lid . </s>
# ===================
# 입력:<s> 그 거리의 시작점부터 끝까지 이동하는 데엔 1시간이 걸려 . </s>
# 출력(greedy decoding):I have been to know that day , and the end of the end of the end of the end of the end . </s>
# 답안:<s> It takes an hour from one end of that street to the other end . </s>
# ===================
# 입력:<s> 자신을 사랑하고 자랑스럽게 생각하는 것은 좋은 일이에요 . </s>
# 출력(greedy decoding):I know that I have to know how to do . </s>
# 답안:<s> Loving and being proud of myself is a good thing . </s>
# ===================
# 입력:<s> 그 누구도 그의 강속구를 쳐낼 수는 없어 . </s>
# 출력(greedy decoding):No need to know that . </s>
# 답안:<s> No one can hit his fastballs . </s>
# ===================
# 입력:<s> 저는 오늘 돈을 많이 벌어서 기분 좋아요 . </s>
# 출력(greedy decoding):I have to know how I have to get money today . </s>
# 답안:<s> I ’ m really happy because I earned a lot of money today . </s>
# ===================
# 입력:<s> 그 회사 담당자 문의 건은 완료되었는지요 ? </s>
# 출력(greedy decoding):I know the company , I have to know the company ? </s>
# 답안:<s> Is the inquiry completed which is from the person in the company ? </s>
# ===================
# 입력:<s> 영어 공부 좀 하려고 하는데 어려워요 . </s>
# 출력(greedy decoding):I have to know how I have to study English . </s>
# 답안:<s> I am trying to study English but it is not easy . </s>
# ===================
# 입력:<s> 팀 내 한국인 관리자에게 문의 바랍니다 . </s>
# 출력(greedy decoding):I know the team , I have to ask you to ask my team . </s>
# 답안:<s> Ask the Korean manager in the team . </s>
# ===================
# 입력:<s> 나는 당신이 무엇을 걱정하는지 알고 있어요 . </s>
# 출력(greedy decoding):I know what you know what you are . </s>
# 답안:<s> I know what you worry about . </s>
# ===================
# 입력:<s> 당신은 파트타임으로 일합니까 아니면 풀타임으로 일합니까 ? </s>
# 출력(greedy decoding):I know the event , I have to get a few days ? </s>
# 답안:<s> Are you a part-time worker or full-time worker ? </s>
# ===================
# 입력:<s> 그것은 제 과제에 포함되어 있지 않아요 . </s>
# 출력(greedy decoding):It is not to be the price of the price . </s>
# 답안:<s> It ’ s not in my assignment . </s>
# ===================
# 입력:<s> 너의 친구는 모임이 서울에서 있는거니 ? </s>
# 출력(greedy decoding):I know your friend , I have to know Seoul ? </s>
# 답안:<s> Does your friend have a meeting in Seoul ? </s>
# ===================
# 입력:<s> 우리가 반드시 이기고 말 거야 . </s>
# 출력(greedy decoding):I know the first time , I have to know . </s>
# 답안:<s> We will definitely win . </s>
# ===================
# 입력:<s> 다음 번에는 규정을 따라주시기 바랍니다 . </s>
# 출력(greedy decoding):I have to know the following documents next time . </s>
# 답안:<s> Please follow the regulations next time . </s>
# ===================
# 입력:<s> 저는 스미소니언 박물관을 갈 겁니다 . </s>
# 출력(greedy decoding):I have to go to the museum . </s>
# 답안:<s> I 'm visiting the Smithsonian Museum . </s>
# ===================
# 입력:<s> 높은 자외선과 미세먼지를 최대한 피하세요 . </s>
# 출력(greedy decoding):I need to know the time , but there are more than the time . </s>
# 답안:<s> Avoid high UV and fine dust as much as you can . </s>
# ===================
# 입력:<s> 인보이스가 준비되면 제게 연락해 주세요 . </s>
# 출력(greedy decoding):I know the invoice number of the invoice . </s>
# 답안:<s> Please contact me when the invoice is ready . </s>
# ===================
# 입력:<s> 이 강아지 사료는 건강에 좋아요 . </s>
# 출력(greedy decoding):I have to know this dog , but I have to know . </s>
# 답안:<s> This dog food is good for your dog 's health . </s>
# ===================
# 입력:<s> 그와 같은 한국인인 것이 자랑스럽습니다 . </s>
# 출력(greedy decoding):I know that I have to know about him . </s>
# 답안:<s> I am very proud of being a Korean like him . </s>
# ===================
# 입력:<s> 그는 카네기멜런대학 컴퓨터 공학과 교수입니다 . </s>
# 출력(greedy decoding):He said he is from the computer , but I have to know the computer . </s>
# 답안:<s> He is a professor of computer science at Carnegie Mellon University . </s>
# ===================
# 입력:<s> 당신은 몸에 열이 많이 나세요 ? </s>
# 출력(greedy decoding):I know you have to know the house ? </s>
# 답안:<s> Do you have a high temperature ? </s>
# ===================
# 입력:<s> 햇빛 때문에 좀 성가시지요 ? </s>
# 출력(greedy decoding):I have to know if I have a little phone number ? </s>
# 답안:<s> Is the sun bothering you ? </s>
# ===================
# 입력:<s> 괜찮은 국산제품을 추천해주시기 바랍니다 . </s>
# 출력(greedy decoding):I have to know the same amount of the main machine . </s>
# 답안:<s> Please recommend me good domestic products . </s>
# ===================
# 입력:<s> 우리의 직원은 상품을 받았습니다 . </s>
# 출력(greedy decoding):We have been to know the company before . </s>
# 답안:<s> Our employee received the prize . </s>
# ===================
# 입력:<s> 발생한 문제는 해결되셨나요 ? </s>
# 출력(greedy decoding):What is the problem of the problem , but the problem of the problem ? </s>
# 답안:<s> Was the problem solved that had occurred ? </s>
# ===================
# 입력:<s> 경치가 정말 장관이었습니다 . </s>
# 출력(greedy decoding):I have been to know the sky of the sky . </s>
# 답안:<s> The view took my breath away . </s>
# ===================
# 입력:<s> 주말에 나와서까지 일을 하든 어떻게 해서든 다음 주 초에 니가 물건을 받을 수 있도록 우리 팀들을 푸쉬해 보도록 하겠습니다 . </s>
# 출력(greedy decoding):I will try to make a meeting with the next week and I will be able to get a meeting with the same time . </s>
# 답안:<s> I will push my teams to make sure you can receive the product early next week even if we 'll need to work over the weekend . </s>
# ===================
# 입력:<s> 나는 모든 종류의 화물 손상 및 선적 관련 사항을 관여할 것이고 가장 좋은 결과를 만들어 낼 것이에요 . </s>
# 출력(greedy decoding):I have to be a good result of the product , and the same time of the same time . </s>
# 답안:<s> I would be administrating every aspect of carriage damage and details to create the best results . </s>
# ===================
# 입력:<s> 도덕적 책임의 전제로서 요구되는 자유란 강제력 없이 자유롭게 선택할 수 있는 인간 행위의 조그마한 영역을 지칭합니다 . </s>
# 출력(greedy decoding):As the result , the power of the power of the power of the power of the power of the human rights of the world . </s>
# 답안:<s> Freedom required as a premise of moral responsibility refers to a small area of human behaviors that can be freely chosen without coercion . </s>
# ===================
# 입력:<s> Tv에서 이탈리아 도시나 아니면 멋진 시골 풍경들을 소개하는 여행 프로그램을 가끔씩 합니다 . </s>
# 출력(greedy decoding):I have to know the traditional culture of the world , and the world , and the world . </s>
# 답안:<s> On TV , there are sometimes programs which introduce Italian cities or cool sceneries of countryside . </s>
# ===================
# 입력:<s> 예를 들어 , 습도와 온도 결정에 관한 실험 과정이 언급되지 않았습니다 . </s>
# 출력(greedy decoding):For example , the process of the process of the process of the process of the process of the process of the process . </s>
# 답안:<s> For example , an experimental procedure for moisture and temperature determination are not mentioned . </s>
# ===================
# 입력:<s> 시엠립 톤레삽 호수에서 풀데이 크루즈를 즐기며 , 카메라에 정취를 담아보세요 . </s>
# 출력(greedy decoding):I have to know the video of the camera , and the new place of the new place . </s>
# 답안:<s> Grab your camera and enjoy a full-day all-inclusive cruise around Tonle Sap Lake from Siem Reap . </s>
# ===================
# 입력:<s> 저는 지금까지 경청해주신 의장님과 여러 국가 대표단 여러분 , 감사합니다 . </s>
# 출력(greedy decoding):I know the first time , I have been to meet you and I know the United States . </s>
# 답안:<s> To the chairmen and all the representatives , thank you for listening . </s>
# ===================
# 입력:<s> 그 여자분은 카운터에서 무례한 대접을 받아 기분이 상해 있어요 . </s>
# 출력(greedy decoding):I have to know the name of the office , but I have been to know the right now . </s>
# 답안:<s> She 's offended at being badly treated at the counter . </s>
# ===================
# 입력:<s> 미국 서버와 아시아 서버 각각 이관을 진행해야 합니다 . </s>
# 출력(greedy decoding):I have to know the United States , and the United States , and the United States is needed . </s>
# 답안:<s> Proceed to transfer on each US server and Asian server respectively . </s>
# ===================
# 입력:<s> 실례합니다만 , 선반에 있는 제 가방을 꺼내 주시겠어요 ? </s>
# 출력(greedy decoding):Excuse me , but I know the bag is now ? </s>
# 답안:<s> Excuse me , but could you get me my bag on the rack ? </s>
# ===================
# 입력:<s> 학교를 등록하거나 공부하는 것을 금전적으로 지원하겠다는 겁니다 . </s>
# 출력(greedy decoding):I have to know the school , I have to know the school . </s>
# 답안:<s> I mean , I 'll provide the financial support necessary for enrolling in schools or studying . </s>
# ===================
# 입력:<s> 당신은 어떤 유사점과 차이점을 명명할 수 있습니까 ? </s>
# 출력(greedy decoding):What is you need to know the difference between the smartphone ? </s>
# 답안:<s> What similarities and differences can you name ? </s>
# ===================
# 입력:<s> 당연히 저는 그 일로 기분이 안 좋죠 . </s>
# 출력(greedy decoding):I know that time , I have to know that I have to know . </s>
# 답안:<s> Of course , I feel bad about it . </s>
# ===================
# 입력:<s> 가게에서 일을 시키려고 당신을 사랑한 게 아니에요 . </s>
# 출력(greedy decoding):I have to know the work in the store I have to go to the store . </s>
# 답안:<s> I did n't love you to make you work at the store . </s>
# ===================
# 입력:<s> 우리가 여기에서 100 초점을 조정할 수 있어 ? </s>
# 출력(greedy decoding):If we have to know the total of the table ? </s>
# 답안:<s> Can we adjust the 100 sight from here ? </s>
# ===================
# 입력:<s> 저도 이렇게 맛있는 요리를 만들고 싶어요 . </s>
# 출력(greedy decoding):I have to know this , I have to know this food . </s>
# 답안:<s> I wish I could make food this delicious . </s>
# ===================
# 입력:<s> 그러고 보면 우리의 관계는 참 이상해요 . </s>
# 출력(greedy decoding):I know we have to know the relationship with our relationship . </s>
# 답안:<s> Come to think of it , our relationship is very strange . </s>
# ===================
# 입력:<s> 난 괜찮으니까 이제 그만 가봐 . </s>
# 출력(greedy decoding):I have to know if I have to go to the weather . </s>
# 답안:<s> I 'm fine so you 're free to leave . </s>
# ===================
# 입력:<s> 이것이 사실이라는 게 너무 좋습니다 . </s>
# 출력(greedy decoding):I have to know that this is so there are too much as it is to be a good time . </s>
# 답안:<s> This is so good to be true . </s>
# ===================
# 입력:<s> 내가 홈페이지에 메시지를 남긴 사람이에요 . </s>
# 출력(greedy decoding):I have to know the post office in the website . </s>
# 답안:<s> I am the person who left the message on the website . </s>
# ===================
# 입력:<s> 실패할까 봐 걱정이 되고 불안해요 . </s>
# 출력(greedy decoding):I have to know how I have to know the school . </s>
# 답안:<s> I 'm nervous and afraid of failure . </s>
# ===================
# 입력:<s> 당신은 나 때문에 자유롭지 않잖아요 . </s>
# 출력(greedy decoding):I have to know the way to have been to the time . </s>
# 답안:<s> You are not free because of me . </s>
# ===================
# 입력:<s> 내 집은 통제되는 곳에 있어요 . </s>
# 출력(greedy decoding):I have to know the house of my house . </s>
# 답안:<s> My house is located in a restricted area . </s>
# ===================
# 입력:<s> 저는 지금 바로 이용하도록 하겠어요 . </s>
# 출력(greedy decoding):I have to know the way to know the time now . </s>
# 답안:<s> I 'll use it right away . </s>
# ===================
# 입력:<s> 영업부에 근무하는 Jake씨 연결 부탁합니다 . </s>
# 출력(greedy decoding):I know the case of the company , and I have to know the same time . </s>
# 답안:<s> Can I speak to Jake in the sales team ? </s>
# ===================
# 입력:<s> 이전에 한국에서 판매한 경험이 있습니까 ? </s>
# 출력(greedy decoding):I have to know the event before I have been now ? </s>
# 답안:<s> Do you have any experience of selling previously in Korea ? </s>
# ===================
# 입력:<s> 치킨의 종류에 대해 자세히 알아보자 . </s>
# 출력(greedy decoding):I know the design of the design of the product . </s>
# 답안:<s> Let 's study deeply about different kinds of chicken . </s>
# ===================
# 입력:<s> 수입담당자 이름과 연락처를 알려주시길 바랍니다 . </s>
# 출력(greedy decoding):I know the name of the name of the name of the name . </s>
# 답안:<s> Please tell me the name and contact number of the person in charge of import . </s>
# ===================
# 입력:<s> 빨리 날씨가 풀려야 할 텐데요 . </s>
# 출력(greedy decoding):I have to know if there is a cold . </s>
# 답안:<s> I hope the weather gets warmer soon . </s>
# ===================
# 입력:<s> 우리는 노후를 생각해야 해요 . </s>
# 출력(greedy decoding):We have to know the first time , and we need to know . </s>
# 답안:<s> We have to think about our later years . </s>
# ===================
# 입력:<s> 그래도 내용을 이해하셨으니 다행이에요 . </s>
# 출력(greedy decoding):I have to know the contents of the contents . </s>
# 답안:<s> But I 'm glad you understood the content . </s>
# ===================
# 입력:<s> 우리 선생님은 우리를 사랑하십니다 . </s>
# 출력(greedy decoding):I have to know the first time ago . </s>
# 답안:<s> My teacher loves us . </s>
# ===================
# 입력:<s> 그런데 어느 날 나는 아침에 일어났을 때 몸을 일으킬 수 없을 정도의 두통을 호소했었어 . </s>
# 출력(greedy decoding):But I can not be able to be able to be a long time . </s>
# 답안:<s> But one morning , I woke up with a heavy headache and could not get up . </s>
# ===================
# 입력:<s> 우리의 시스템은 너의 계좌에 적혀있는 은행 정보를 가지고는 거래를 처리할 수 없었어요 . </s>
# 출력(greedy decoding):We have to pay the bank account of the bank account of the bank account . </s>
# 답안:<s> Our system was not able to process the transaction with the bank info listed on your account . </s>
# ===================
# 입력:<s> 저는 이번 주 일요일에 아버지와 야구 경기 보러 가기로 했어요 . </s>
# 출력(greedy decoding):I have to go to watch my father on Sunday . </s>
# 답안:<s> I 'm supposed to be at a baseball game with my father this Sunday . </s>
# ===================
# 입력:<s> 내가 네 옆에 있었으면 도움 줄 수 있을 텐데 . </s>
# 출력(greedy decoding):I know you can be able to be next to you . </s>
# 답안:<s> If I were beside you , I could help you . </s>
# ===================
# 입력:<s> 프로그램 이송 시작 시각 이전에 문서 체크를 시도해 주십시오 . </s>
# 출력(greedy decoding):I have to check the report of the program before the program . </s>
# 답안:<s> Please attempt to check-in documents prior to the migration start time . </s>
# ===================
# 입력:<s> 귀국 항공편은 1개월짜리 항공편으로 귀국 편은 오픈으로 끊으시길 바랍니다 . </s>
# 출력(greedy decoding):I have to know the flight ticket , so I have to get a ticket to the ticket . </s>
# 답안:<s> I want you to take the one-month open return ticket . </s>
# ===================
# 입력:<s> 향후 ooo의 조약 수립 과정은 어떻게 진행되는지 알려주시면 감사하겠습니다 . </s>
# 출력(greedy decoding):I know how to know the result of the process of the process of the process of the process of the process of the process . </s>
# 답안:<s> I will also be thankful if you let me know how the process of entering into a treaty with ooo will proceed from now on . </s>
# ===================
# 입력:<s> 나는 해 질 녘에 해변 근처에 있는 목양지를 찾았어요 . </s>
# 출력(greedy decoding):I know the park where I have to go to the beach . </s>
# 답안:<s> I found a sheep meadow near a beach during sunset . </s>
# ===================
# 입력:<s> 유인 수류탄은 특성이 강하지만 , 일부 상황에서 유용합니다 . </s>
# 출력(greedy decoding):I know the same time , but I need to know the same time . </s>
# 답안:<s> Decoy grenade , while gimmicky , is useful in certain circumstances . </s>
# ===================
# 입력:<s> 나는 너랑 데이트하면서 너의 영화 취향을 알았어 . </s>
# 출력(greedy decoding):I know you know you , I know you . </s>
# 답안:<s> I knew your movie taste by dating you . </s>
# ===================
# 입력:<s> 8월 2일까지 답이 없다면 지원은 자동 취소됩니다 . </s>
# 출력(greedy decoding):If there is any problem , I have to receive the answer to the reply . </s>
# 답안:<s> The application is automatically canceled if there is no reply by August 2nd . </s>
# ===================
# 입력:<s> 1 번을 제외하고 모든 제품이 내일 선적될까요 ? </s>
# 출력(greedy decoding):When can you know the product , we have been going to the product tomorrow ? </s>
# 답안:<s> Will every product except number one be shipped tomorrow ? </s>
# ===================
# 입력:<s> 그래야 내가 당신의 마음을 전달할 수 있죠 . </s>
# 출력(greedy decoding):I know what I have to ask you to send your heart . </s>
# 답안:<s> That 's how I can convey your mind . </s>
# ===================
# 입력:<s> 드라이 마티니는 세계에서 5번째로 인기 있는 칵테일입니다 . </s>
# 출력(greedy decoding):I have to know the world in the world of the world . </s>
# 답안:<s> Dry martini is the fifth most popular cocktail in the world . </s>
# ===================
# 입력:<s> 우리는 안전위험 결과를 통한 최적화 솔루션을 제안합니다 . </s>
# 출력(greedy decoding):We need to know the result of the result of the result . </s>
# 답안:<s> We suggest optimal solutions through safety risk results . </s>
# ===================
# 입력:<s> 런웨이와 패션 화보에서 다양한 모습을 보여주고 있어요 . </s>
# 출력(greedy decoding):I have to know the fashion of various cultures . </s>
# 답안:<s> She shows various looks in a runway and fashion editorials . </s>
# ===================
# 입력:<s> 당신은 왜 나에게 얼굴을 보여 주지 않습니까 ? </s>
# 출력(greedy decoding):Why did you know why you know what you have to me ? </s>
# 답안:<s> Then why do n't you show me your face ? </s>
# ===================
# 입력:<s> 스타벅스 부평점에서 나오면 오른쪽으로 걸어서 직진하세요 . </s>
# 출력(greedy decoding):I have to go to the exit of the exit of the street . </s>
# 답안:<s> When you leave the Bupyeong Starbucks , head right and go straight . </s>
# ===================
# 입력:<s> 제 바지 치수를 재주실 수 있습니까 ? </s>
# 출력(greedy decoding):Can I know my bag ? </s>
# 답안:<s> Can you measure my pants ? </s>
# ===================
# 입력:<s> 나는 독특한 분위기를 가진 여성을 좋아해요 . </s>
# 출력(greedy decoding):I know I know the unique taste of the fashion . </s>
# 답안:<s> I like women with unique auras . </s>
# ===================
# 입력:<s> 김치는 우리 한국 음식 중 최고예요 . </s>
# 출력(greedy decoding):There are the most popular food of Korea . </s>
# 답안:<s> Kimchi is the best food among our Korean food . </s>
# ===================
# 입력:<s> 앞으로 후회할 짓을 하고 살지 않겠어요 . </s>
# 출력(greedy decoding):I know what I have to do to do in now . </s>
# 답안:<s> I will not do anything that would regret . </s>
# ===================
# 입력:<s> 저희와 함께 사진 한 장 찍어주시겠어요 ? </s>
# 출력(greedy decoding):I know you know you and I know you ? </s>
# 답안:<s> Could you take a picture with us ? </s>
# ===================
# 입력:<s> 이번에는 다른 도시에 갈 거야 . </s>
# 출력(greedy decoding):I have to go to other countries this time . </s>
# 답안:<s> I will go to a different city this time . </s>
# ===================
# 입력:<s> 당신이 다시 보내주신 파일을 확인했습니다 . </s>
# 출력(greedy decoding):I know you have to know the file you sent . </s>
# 답안:<s> I confirmed the file you sent me again . </s>
# ===================
# 입력:<s> 어쩐지 주스 맛이 이상하게 새콤했어요 . </s>
# 출력(greedy decoding):I have to know that it is the taste of the food . </s>
# 답안:<s> No wonder the juice taste was strangely sour . </s>
# ===================
# 입력:<s> 학생들은 열정적이지 않은 것 같아요 . </s>
# 출력(greedy decoding):I have to know the students yet . </s>
# 답안:<s> I do n't think the students are passionate enough . </s>
# ===================
# 입력:<s> 저는 그녀가 외국에 있어서 좋습니다 . </s>
# 출력(greedy decoding):I have to know how she is now . </s>
# 답안:<s> I 'm happy because she is abroad . </s>
# ===================
# 입력:<s> 내 친구 팔이 좀 거슬리네요 . </s>
# 출력(greedy decoding):I have to know my friend before . </s>
# 답안:<s> My friend 's arm bothers me . </s>
# ===================
# 입력:<s> 그를 개성 있게 해 주잖아요 . </s>
# 출력(greedy decoding):I need to know him to know him . </s>
# 답안:<s> It gives him character . </s>
# ===================
# 입력:<s> 작가의 소설은 특이하게 구성되어 있어 . </s>
# 출력(greedy decoding):I have to know the author , but there are the same as a movie . </s>
# 답안:<s> The author 's novel is uniquely organized . </s>
# ===================
# 입력:<s> 우체국에 연락해서 제품을 반품하세요 . </s>
# 출력(greedy decoding):I know the product , I have to contact you . </s>
# 답안:<s> Return the product by contacting the post office . </s>
# ===================
# 입력:<s> 그리고 내가 매일 당신 집에 가서 짧은 시간 동안 당신을 만나지만 , 나는 항상 혼자 있는 느낌이 들어 . </s>
# 출력(greedy decoding):And I 'm always happy to go to your house every day . </s>
# 답안:<s> I always get the feeling that I 'm alone as well , even though I go to your house every day and see you for short periods of time </s>
# ===================
# 입력:<s> 내년에 내가 거기 갈 예정이긴 한데 정확한 날짜는 아직 몰라 , 확실히 일정 잡히면 알려줄게 . </s>
# 출력(greedy decoding):I have to know if I have a exact date of the exact date of the date of the exact time , I will be still have </s>
# 답안:<s> I 'm supposed to go there next year , but I 'm not sure about the certain date , I will let you know when I make my plan </s>
# ===================
# 입력:<s> 그런데 그는 범죄행위 이외에 돈을 벌 방법이 없고 , 한계를 느꼈기에 범죄에 가담했을 것이에요 . </s>
# 출력(greedy decoding):But he is not to be able to be able to be a person who are not to be able to be a person in the same way . </s>
# 답안:<s> However , he must have involved himself in crime as he felt his limits and there was nothing else to do but a crime to earn money . </s>
# ===================
# 입력:<s> 혹은 , 당신이 개인정보 확인에 동의해 주신다면 , 저희 쪽에서 그 버전을 확인해 보겠습니다 . </s>
# 출력(greedy decoding):Or you have to check the data , and we will check the data . </s>
# 답안:<s> Or , if you agree to the confirmation of your personal information , I will personally check the version . </s>
# ===================
# 입력:<s> 만약 버튼이 표시하는 간헐적인 위치에 있다면 , 그것에는 약간의 변칙이 존재합니다 . </s>
# 출력(greedy decoding):If there are the number of the button , there is no one of the amount of the amount of the amount of the right . </s>
# 답안:<s> If the button is in the intermittence position that indicates there 's some anomaly . </s>
# ===================
# 입력:<s> 사람들이 많이 검색하는 단어 및 문장 위주로 적어주세요 . 포르투갈어로 . </s>
# 출력(greedy decoding):I know the words , I have to know the problem with a lot of words . </s>
# 답안:<s> Please write using words and sentences that many people search for in Portuguese . </s>
# ===================
# 입력:<s> 난 가만히 못 있고 심심해하는 성격 좀 고쳐야 돼 . </s>
# 출력(greedy decoding):I have to know if I have to be able to be able to find it . </s>
# 답안:<s> I should fix this habit of not being able to stay and do nothing . </s>
# ===================
# 입력:<s> 진이 그가 내 위에서 나를 공격하는 영상과 사진을 찍었어요 . </s>
# 출력(greedy decoding):I have been to see the picture of my picture of me . </s>
# 답안:<s> Jin took pictures and videos of him on top of me attacking . </s>
# ===================
# 입력:<s> 그들은 그 제품을 어디에서 사용하고 있는지 알고 싶어 해요 . </s>
# 출력(greedy decoding):They know that we know how to know the product is ? </s>
# 답안:<s> They want to know where the products are used . </s>
# ===================
# 입력:<s> 그러나 너는 단 한 번도 사진을 보내지 않았어 . </s>
# 출력(greedy decoding):But I know you have been to send you a picture . </s>
# 답안:<s> However , you have n't sent a photo even once . </s>
# ===================
# 입력:<s> 혹시 다른 방법이 있으면 아낌없는 조언 부탁드립니다 . </s>
# 출력(greedy decoding):I know if there are any other ways to know if you are there are any other than you know . </s>
# 답안:<s> If there 's another way , please do n't think too much to advise us . </s>
# ===================
# 입력:<s> 그 아래로 끝도 없이 시커먼 블랙홀이 펼쳐졌다 . </s>
# 출력(greedy decoding):The number of the fire is the road . </s>
# 답안:<s> It was an endless black hole below it . </s>
# ===================
# 입력:<s> 메뉴 가격 정책 및 제품 관리는 중요하다 . </s>
# 출력(greedy decoding):We have to know the price of the product of the product . </s>
# 답안:<s> Pricing policy of the menu and product management is important . </s>
# ===================
# 입력:<s> 나는 현재 하루라도 빨리 돈을 모으고 싶어 . </s>
# 출력(greedy decoding):I have to know the money before I have been working . </s>
# 답안:<s> I want to save money as soon as possible . </s>
# ===================
# 입력:<s> 내가 연출해야만 했던 음악은 일곱 조각의 나머지이에요 . </s>
# 출력(greedy decoding):I know the music of the music of the movie was in the middle of the middle of the middle of the world . </s>
# 답안:<s> The music that I must choreograph is seven pieces of the remainder . </s>
# ===================
# 입력:<s> 같이 한국 음식 먹으러 나가지 않을래요 ? </s>
# 출력(greedy decoding):I know I have to go to Korea with Korean food ? </s>
# 답안:<s> Wo n't you go out for Korean food together ? </s>
# ===================
# 입력:<s> 그러면 저는 앞으로 현 계약에서 빠지겠습니다 . </s>
# 출력(greedy decoding):Then I have to know the right now , I have to know the right now . </s>
# 답안:<s> If so , I will drop out of the current contract . </s>
# ===================
# 입력:<s> 감기에 걸리기 전에 뜨거운 물로 샤워해요 . </s>
# 출력(greedy decoding):I have to know the cold time ago , but I have to get it before it . </s>
# 답안:<s> Take a hot shower before you get a cold . </s>
# ===================
# 입력:<s> 저기 있는 물건 좀 내게 가져다주세요 . </s>
# 출력(greedy decoding):I know the product before I have to know the product . </s>
# 답안:<s> Please get me the thing from there . </s>
# ===================
# 입력:<s> 당신에게 멋진 남자 친구가 생기길 바랄게요 . </s>
# 출력(greedy decoding):I have to know you as a great boyfriend . </s>
# 답안:<s> I hope you to have a nice boyfriend . </s>
# ===================
# 입력:<s> 이것은 진한 초콜릿과 생크림이 특징입니다 . </s>
# 출력(greedy decoding):We have to know the skin and the skin . </s>
# 답안:<s> It 's special features are dark chocolate and fresh cream . </s>
# ===================
# 입력:<s> 뭐든지 가꾸지 않으면 시드는 법이죠 . </s>
# 출력(greedy decoding):I have to know if you have to know if you have to know . </s>
# 답안:<s> Everything gets withered away when you do n't take care of it . </s>
# ===================
# 입력:<s> 성공과 행복은 자기 자신에게 달려있습니다 . </s>
# 출력(greedy decoding):I know what I know what I have to know . </s>
# 답안:<s> Success and happiness depends on oneself . </s>
# ===================
# 입력:<s> 이 부분은 그냥 잘라 버리세요 . </s>
# 출력(greedy decoding):I have to know this case of the error . </s>
# 답안:<s> Just cut this part off . </s>
# ===================
# 입력:<s> 그 경기에 유명 선수들이 참가했습니다 . </s>
# 출력(greedy decoding):I have to know the game of the game . </s>
# 답안:<s> Famous players participated in the game . </s>
# ===================
# 입력:<s> 당신에 대한 이야기를 하려고 합니다 . </s>
# 출력(greedy decoding):I know you know you about you . </s>
# 답안:<s> I am gon na talk about you . </s>
# ===================
# 입력:<s> 요청하신 사항도 포함하여 진행할 예정입니다 . </s>
# 출력(greedy decoding):I have to know the contract number of the payment . </s>
# 답안:<s> We will proceed including what you have requested . </s>
# ===================
# 입력:<s> 이것은 단골을 만드는 좋은 방법입니다 . </s>
# 출력(greedy decoding):We have to know how many things are . </s>
# 답안:<s> This is a good way to make regular customers . </s>
# ===================
# 입력:<s> 그때 바에는 다른 호스트도 있었습니다 . </s>
# 출력(greedy decoding):I have to know that you have to know that time . </s>
# 답안:<s> There were other hosts in the bar . </s>
# ===================
# 입력:<s> 저에게 담당자를 이야기해주셔서 감사합니다 . </s>
# 출력(greedy decoding):I know I know the person who are from the Korean . </s>
# 답안:<s> Thank you for telling me the person in charge . </s>
# ===================
# 입력:<s> 나는 마닐라에 친구가 없습니다 . </s>
# 출력(greedy decoding):I have to know what I have to go to Manila . </s>
# 답안:<s> I do n't have a friend in Manila . </s>
# ===================
# 입력:<s> 빨래가 비에 젖어버렸습니다 . </s>
# ...
# 답안:<s> Will you come to my party next Saturday ? </s>
# ===================
# 입력:<s> 당신은 미팅 사이트에 간 적 있나요 ? </s>
# 출력(greedy decoding):I know you have to go to the website ? </s>
# 답안:<s> Have you ever visited the dating web site ? </s>
# ===================
# 입력:<s> 이 운동화는 내가 직접 꾸민 운동화야 . </s>
# 출력(greedy decoding):I have to know this book , but I have to know the game . </s>
# 답안:<s> I designed those snickers myself . </s>
# ===================
# 입력:<s> 우리가 전에 대화를 나눈 적이 있나요 ? </s>
# 출력(greedy decoding):I know we have to know you before you know ? </s>
# 답안:<s> Have we chatted before ? </s>
# ===================
# 입력:<s> 제품을 판매하는 나로서 굉장한 힘이 돼요 . </s>
# 출력(greedy decoding):I have to know the product of the product of the product . </s>
# 답안:<s> This Means a lot to me as a seller . </s>
# ===================
# 입력:<s> 데이비스는 이 주장에 대해 재반박했습니다 . </s>
# 출력(greedy decoding):I have to know the following . </s>
# 답안:<s> Davis contradicted again on this argument . </s>
# ===================
# 입력:<s> 이 시계는 15분이 늦게 흘러갑니다 . </s>
# 출력(greedy decoding):I have been to go to the festival , but I have been to the end of the day . </s>
# 답안:<s> This watch runs fifteen minutes slow . </s>
# ===================
# 입력:<s> 특정 목표는 결정을 내림으로써 유도된다 . </s>
# 출력(greedy decoding):I have to know the result of the result of the result of the result of the future . </s>
# 답안:<s> A specific goal is intended by making a decision . </s>
# ===================
# 입력:<s> 이 소스는 콩과 올리브오일로 만들었습니다 . </s>
# 출력(greedy decoding):I have to know this area , and the water . </s>
# 답안:<s> This sauce is made of bean and olive oil . </s>
# ===================
# 입력:<s> 우린 서로 한눈에 반했어요 . </s>
# 출력(greedy decoding):We have to know we have to go to each other . </s>
# 답안:<s> We fell in love with each other at first sight . </s>
# ===================
# 입력:<s> 내용 전달에 오해가 있었습니다 . </s>
# 출력(greedy decoding):I have been to know the contents of the contents . </s>
# 답안:<s> There was a misunderstanding while delivering the contents . </s>
# ===================
# 입력:<s> 촬영 일정이 어떻게 되나요 ? </s>
# 출력(greedy decoding):What is the schedule of the schedule ? </s>
# 답안:<s> What is the shooting schedule ? </s>
# ===================
# 입력:<s> 폐렴이 되기 직전입니다 . </s>
# 출력(greedy decoding):I have to know the first time ago . </s>
# 답안:<s> It 's on the borderline of pneumonia . </s>
# ===================
# 입력:<s> 이것은 비상시에만 사용해주세요 . </s>
# 출력(greedy decoding):I have to know the number of the application . </s>
# 답안:<s> Please use it only in an emergency . </s>
# ===================
# 입력:<s> 서리가 내리자마자 얼어버렸어 . </s>
# 출력(greedy decoding):I have been to know the first time ago . </s>
# 답안:<s> It was froze as soon as the frost falls . </s>
# ===================
# 입력:<s> 아마도 내가 중학교 2학년 진로 탐색 시간 때였고 그때 진로 박람회를 갔는데 친구들과 선생님과 여러 모르는 사람들이 있었어요 . </s>
# 출력(greedy decoding):I was studying English and I was studying at the school and I was studying at the school . </s>
# 답안:<s> Probably it was the career class when I was in the second grade of middle school and at then , I went to a career fair and there were </s>
# ===================
# 입력:<s> 태양제는 밤이 가장 긴 날 , 동지인 매년 6월 24일을 전후로 약 일주일간 열린다 . </s>
# 출력(greedy decoding):On the night , the day of the day of the day of the day of the day of the day of the day of the day of the day . </s>
# 답안:<s> The sun festival is held every year around June 24 , the day of the longest night , for about a week . </s>
# ===================
# 입력:<s> 한강에서 일어난 괴물 둘을 트럼펫의 시끄러운 소리로 혼란 시키고 수류탄으로 쏘아 죽였어요 . </s>
# 출력(greedy decoding):I have been to be a boy who had a little bit of the road , and the police officer and the first time . </s>
# 답안:<s> The monsters who woke up from the Han river were confused to hear loud trumpet sounds and were killed by shooting grenades . </s>
# ===================
# 입력:<s> 연구 결과가 논리적으로 도출되었다고 볼 수 없고 그 결과를 신뢰할 수 없습니다 . </s>
# 출력(greedy decoding):As the result , I have to see the result of the result of the result of the result of the result . </s>
# 답안:<s> The results were not established logically , and it is not credible . </s>
# ===================
# 입력:<s> 전류는 발전기가 있는 베이스와 컴퓨터에서 헤드로 가기 위해 이들 중 6개를 통과해요 . </s>
# 출력(greedy decoding):I have to know the game of the computer and the computer of the computer . </s>
# 답안:<s> The current travels through 6 of these to get from the base containing the generator and computer to the head . </s>
# ===================
# 입력:<s> 나는 13일 저녁에 필리핀 마닐라에서 친한 한국인 형님을 사업차 만나야 해요 . </s>
# 출력(greedy decoding):I have to meet the Korean hotel in the Philippines in the Philippines . </s>
# 답안:<s> I need to meet my close Korean friend in the evening of the 13th to talk business . </s>
# ===================
# 입력:<s> 난 구글 계정은 있지만 너의 영상을 어떻게 볼 수있는지 모르겠네 . </s>
# 출력(greedy decoding):I know I know what I have to see your account , but I know what I have to know . </s>
# 답안:<s> I have a Google account but there 's no idea how to watch your video . </s>
# ===================
# 입력:<s> 내가 새로운 헤드 캡과 자석을 너에게 보내줄 테니 걱정하지 마 . </s>
# 출력(greedy decoding):I have to know the new product , but I have to send you to you to you to you . </s>
# 답안:<s> I 'll send you a new head cap and a magnet , so do n't worry . </s>
# ===================
# 입력:<s> 영원히 존재 할 수 있게 지어진 것은 아무것도 없어요 . </s>
# 출력(greedy decoding):I know what you have to know what you are . </s>
# 답안:<s> Nothing 's built to last anymore . </s>
# ===================
# 입력:<s> 이건 해외 인기 상품 및 핫딜 상품 공유 사이트입니다 . </s>
# 출력(greedy decoding):This is the Korean product , and the product is the product of the product . </s>
# 답안:<s> This website is for sharing popular foreign products and hot deals . </s>
# ===================
# 입력:<s> 단지 2t 원 컬러를 원하신다면 Accent/Base 구분을 해주시면 됩니다 . </s>
# 출력(greedy decoding):If you know the product , you need to know the size of the product . </s>
# 답안:<s> If you need simply a 2 tone color , make sure to distinguish between Accent and Base . </s>
# ===================
# 입력:<s> 참고를 위해 당신께 제가 이미지를 함께 보내 드립니다 . </s>
# 출력(greedy decoding):I know you know you as I know you . </s>
# 답안:<s> I send you these images as a reference . </s>
# ===================
# 입력:<s> 14011 장비는 작업 범위가 워크숍에서 삼성 야드로 이관되었습니다 . </s>
# 출력(greedy decoding):I have to know the sales of the company , and the company is the company . </s>
# 답안:<s> The scope of work for 14011 equipment was transferred from Workshop to Samsung yard . </s>
# ===================
# 입력:<s> 지금 생각해보면 그는 친절하고 자세하게 가르쳐준 고마운 친구입니다 . </s>
# 출력(greedy decoding):I know that he is now I have to know about the Korean friends . </s>
# 답안:<s> Now that I think of it , he was a good friend who taught me kindly and detailly . </s>
# ===================
# 입력:<s> 이 연속 출판물은 너무 기술적인 것 같습니다 . </s>
# 출력(greedy decoding):I have to know the test of this event . </s>
# 답안:<s> This serial publication seems too technical . </s>
# ===================
# 입력:<s> 그런 피상적인 이유에 원인을 돌려서는 안 됩니다 . </s>
# 출력(greedy decoding):I know that reason , there are no matter what is . </s>
# 답안:<s> Such superficial reasons should not be the cause . </s>
# ===================
# 입력:<s> 이것을 감사의 뜻으로 당신께 선물로 드리고 싶습니다 . </s>
# 출력(greedy decoding):I know I have to know this , I know you know the present . </s>
# 답안:<s> I would like to give this as a gift to express my gratitude . </s>
# ===================
# 입력:<s> 일본에서 재수입 통관에 문제가 없을지 걱정 입니다 . </s>
# 출력(greedy decoding):I have to know the problem of Japan , but I have to know the problem . </s>
# 답안:<s> I 'm so worried about whether there is no problem when reimporting clearance in Japan . </s>
# ===================
# 입력:<s> 알았어 , 나한테 그 사실을 알려줘서 고마워 . </s>
# 출력(greedy decoding):I know that I know that I know that you know . </s>
# 답안:<s> Ok , thanks for letting me know . </s>
# ===================
# 입력:<s> 해가 질 때까지 나는 파티를 할 거야 . </s>
# 출력(greedy decoding):I have to know the day of the year . </s>
# 답안:<s> I 'll party until the sun goes down . </s>
# ===================
# 입력:<s> 내일 아침 이동 수단이 필요한데 예약 가능한가요 ? </s>
# 출력(greedy decoding):I have to know the reservation tomorrow morning , but I need to get a reservation ? </s>
# 답안:<s> Can I make a reservation for transportation tomorrow morning ? </s>
# ===================
# 입력:<s> 그리고 나 8월에 엄마 집으로 들어갈 거야 . </s>
# 출력(greedy decoding):And I know the house , I have been going to go home . </s>
# 답안:<s> And I 'm going to move to my mother 's house in August . </s>
# ===================
# 입력:<s> 내가 오기 전부터 이미 문제가 있었어 . </s>
# 출력(greedy decoding):I have been to know the problem ago . </s>
# 답안:<s> There had been problems before I got there . </s>
# ===================
# 입력:<s> 내가 여러 차례에 걸쳐 서면으로 경고했는데 . </s>
# 출력(greedy decoding):I have to know many times , I have been to be able to know . </s>
# 답안:<s> I warned him several times by letter . </s>
# ===================
# 입력:<s> 저는 우리가 원만한 협의를 하면 좋겠어요 . </s>
# 출력(greedy decoding):I know we need to know the business . </s>
# 답안:<s> I hope we can come to a amicable agreement . </s>
# ===================
# 입력:<s> 이 세 바이올린은 나의 참고대상입니다 . </s>
# 출력(greedy decoding):I have to know the three years ago . </s>
# 답안:<s> These three violins are my references . </s>
# ===================
# 입력:<s> 정확히 7시에 당신을 데리러 갈게요 . </s>
# 출력(greedy decoding):I have to know the number of you . </s>
# 답안:<s> I 'll pick you up at 7 sharp . </s>
# ===================
# 입력:<s> 당신은 금요일 밤에 나를 기다려야해요 . </s>
# 출력(greedy decoding):I have to know the day of Friday . </s>
# 답안:<s> You have to wait for me on Friday night . </s>
# ===================
# 입력:<s> 우리가 당신의 인생을 바꿔 드립니다 . </s>
# 출력(greedy decoding):I know you have to change your life . </s>
# 답안:<s> We change your life . </s>
# ===================
# 입력:<s> 이것이 바로 그 동명사입니다 . </s>
# 출력(greedy decoding):I have to know the shoes . </s>
# 답안:<s> This is a gerund . </s>
# ===================
# 입력:<s> 내일 3시에 뵙고 싶은데요 . </s>
# 출력(greedy decoding):I have to know the meeting tomorrow . </s>
# 답안:<s> I 'd like to see you tomorrow at three . </s>
# ===================
# 입력:<s> 너 일하느라 많이 힘들겠다 . </s>
# 출력(greedy decoding):I have to know if you have to know the time . </s>
# 답안:<s> You must 've been tired of working . </s>
# ===================
# 입력:<s> 견고한 스테인리스 바디는 쉽게 부러지거나 휘어지지 않아 영구적인 사용이 가능하게 합니다 . </s>
# 출력(greedy decoding):The amount of the water is not easy to use it . </s>
# 답안:<s> The durability of the stainless body helps it to not easily break or bend so that it can be used for a long time . </s>
# ===================
# 입력:<s> 대부분의 베트남 주민들은 약 한 알 때문에 병이 점점 악화하였습니다 . </s>
# 출력(greedy decoding):Most of the most of the Korean people who are young . </s>
# 답안:<s> Most Vietnamese residents had their disease worsened just because of one tablet of the drug . </s>
# ===================
# 입력:<s> 이런 맥락에서 영혼은 '누가 나인가 ' 라는 물음과 일맥상통해요 . </s>
# 출력(greedy decoding):The reason that the most of the soul is the world . </s>
# 답안:<s> In this context , the soul is in line with the question of ‘ who am I ? ' . </s>
# ===================
# 입력:<s> 친절은 지혜보다 중요하고 , 그것을 아는 것이 지혜의 시작입니다 . </s>
# 출력(greedy decoding):I know the reason why I know it is the reason for the time . </s>
# 답안:<s> Kindness is more important than wisdom , and knowing it is the beginning of wisdom . </s>
# ===================
# 입력:<s> 그래서 그 음식점을 지나갈 때면 항상 마음이 불편해요 . </s>
# 출력(greedy decoding):So I have to know if I have a meal . </s>
# 답안:<s> I always feel uncomfortable whenever I pass that food place . </s>
# ===================
# 입력:<s> 진화론과 식민지 개척 , 문화 영향에 대해 알아봅시다 . </s>
# 출력(greedy decoding):I know the world , and I have to introduce the world . </s>
# 답안:<s> Let 's learn about the theory of revolution , colonization and cultural effects . </s>
# ===================
# 입력:<s> 내가 박지성을 존경하는 이유는 축구를 잘해서가 아니다 . </s>
# 출력(greedy decoding):I have to know the soccer player in the park . </s>
# 답안:<s> I do n't respect Ji Seong Park because he 's good at soccer . </s>
# ===================
# 입력:<s> 태국 갔었을 때 너무 뜻깊고 아쉬웠던 여행이었어요 . </s>
# 출력(greedy decoding):I have been going to go to Thailand when I was a student . </s>
# 답안:<s> My trip to Thailand was one of the most meaningful trips so I felt sorry to leave there . </s>
# ===================
# 입력:<s> 당신이 요청한 서류 원본과 함께 담배를 보내겠습니다 . </s>
# 출력(greedy decoding):I have to send you the document you requested . </s>
# 답안:<s> I will send you the cigarettes with the original documents you requested . </s>
# ===================
# 입력:<s> 그 아이들은 각각 다른 학교에 다닙니다 . </s>
# 출력(greedy decoding):The children have been to school . </s>
# 답안:<s> Those kids go to each different school . </s>
# ===================
# 입력:<s> 달걀이 익으면 볶은 밥을 위에 올립니다 . </s>
# 출력(greedy decoding):I have to go to the water and eat it . </s>
# 답안:<s> Put the fried rice on the top of the egg when it is cooked . </s>
# ===================
# 입력:<s> SNS가 대중화되면서 더 빠른 의사소통이 가능해졌다 . </s>
# 출력(greedy decoding):I need to know the development of the development of the development . </s>
# 답안:<s> The development of social networks made faster communication possible . </s>
# ===================
# 입력:<s> 내 생각에 그는 틀림없이 30살일 거에요 . </s>
# 출력(greedy decoding):I have to know that he said . </s>
# 답안:<s> I think he must be 30years old . </s>
# ===================
# 입력:<s> 그 교실에 있는 선생님들은 아주 행복해요 . </s>
# 출력(greedy decoding):I have to know that people have a lot of things . </s>
# 답안:<s> The teachers in that classroom are very happy . </s>
# ===================
# 입력:<s> 그들은 연애인 들의 사생활을 심각하게 간섭해요 . </s>
# 출력(greedy decoding):They have been to the Korean language of the Korean language . </s>
# 답안:<s> They pry into celebrities ' private lives too much . </s>
# ===================
# 입력:<s> 저는 제 딸이 사용할 침대를 샀습니다 . </s>
# 출력(greedy decoding):I have to buy my daughter . </s>
# 답안:<s> I bought a bed for my daughter . </s>
# ===================
# 입력:<s> 이메일 정보를 확인할 수 없다고 합니다 . </s>
# 출력(greedy decoding):I have to check the information that I have to check the information . </s>
# 답안:<s> I was told your email information can not be identified . </s>
# ===================
# 입력:<s> 당신은 모든 것을 가질 수는 없어요 . </s>
# 출력(greedy decoding):You need to know everything . </s>
# 답안:<s> You ca n't have everything . </s>
# ===================
# 입력:<s> 우리는 왜 적절한 동기 부여가 필요한가요 ? </s>
# 출력(greedy decoding):Why are we need to be a job ? </s>
# 답안:<s> Why do we need proper motivation ? </s>
# ===================
# 입력:<s> 저도 이 길을 여자친구와 걸었고요 . </s>
# 출력(greedy decoding):I have to go to the park in the park . </s>
# 답안:<s> I 've also walked on this street with my girlfriend . </s>
# ===================
# 입력:<s> 나는 그녀와 예전에 연락하곤 했어요 . </s>
# 출력(greedy decoding):I know she was now on her . </s>
# 답안:<s> I used to contact her . </s>
# ===================
# 입력:<s> 그래서 나도 그쪽으로 알아보고 있잖아 . </s>
# 출력(greedy decoding):So I know that I have to know . </s>
# 답안:<s> That 's why I 'm looking over there . </s>
# ===================
# 입력:<s> 어제는 당신이 힘들어 보여 안쓰러웠어요 . </s>
# 출력(greedy decoding):I have been to see you yesterday . </s>
# 답안:<s> I felt sorry because you looked tired yesterday . </s>
# ===================
# 입력:<s> 지난 8년간 저는 강아지를 키웠어요 . </s>
# 출력(greedy decoding):I have been to have a dog last time . </s>
# 답안:<s> I bred a dog for the last 8 years . </s>
# ===================
# 입력:<s> 힘들지만 아이를 생각해서 여기까지 왔어요 . </s>
# 출력(greedy decoding):I have been to know if I have been working in the kid . </s>
# 답안:<s> I came all the way here for my baby even though it ’ s hard . </s>
# ===================
# 입력:<s> 미터기보다 요금을 더 높게 부르네요 . </s>
# 출력(greedy decoding):I need to know the money . </s>
# 답안:<s> The fare you 're asking is higher than the taximeter . </s>
# ===================
# 입력:<s> 당신이란 친구 참 나쁘네요 . </s>
# 출력(greedy decoding):I have to know the friend before . </s>
# 답안:<s> You are so mean . </s>
# ===================
# 입력:<s> 원천징수세액이 있을 것으로 생각됩니다 . </s>
# 출력(greedy decoding):I have to know the time . </s>
# 답안:<s> It is expected that there will be an amount of tax to be withheld . </s>
# ===================
# 입력:<s> 치석을 말끔히 제거해 주십시오 . </s>
# 출력(greedy decoding):If you have to know the water , please get a cup . </s>
# 답안:<s> Please remove the tartar . </s>
# ===================
# 입력:<s> 결심이나 계획을 말할 때에요 ? </s>
# 출력(greedy decoding):I know what I have to know the schedule ? </s>
# 답안:<s> When you are talking about your resolution or plan ? </s>
# ===================
# 입력:<s> 사이트를 확인해주세요 , 감사합니다 . </s>
# 출력(greedy decoding):I know the website , I need to know the website . </s>
# 답안:<s> Please check out the website , thank you . </s>
# ===================
# 입력:<s> 나는 일어났더니 배가 고파요 . </s>
# 출력(greedy decoding):I have to go to the classroom . </s>
# 답안:<s> I just woke up and I 'm so hungry . </s>

# %% [markdown]
# # model save

# %%
path = 'trained_model.pth'
torch.save(model.state_dict(), path)

# %% [markdown]
# ## model load

# %%
path = 'trained_model.pth'
model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## TEST

# %%
def test_pad_collate(batch, values=(0, 0), dim=0):
    """
    데이터 로더에 들어가기전에 batch화 할 때 거치는 함수 
    args:
        batch - list of (tensor, label)
    reutrn:
        xs - a tensor of all examples in 'batch' after padding
        ys - a LongTensor of all labels in batch
        ws - a tensor of sequence lengths
    """

    sequence_lengths = torch.Tensor([int(x.shape[dim]) for x in batch]) # 각 batch 마다 길이를 얻어내고 
    # find longest sequence (가장 긴 sequence의 길이를 구함 )
    src_max_len = max(map(lambda x: x.shape[dim], batch))
    # pad according to max_len (max length 만큼 padd를 추가 )
    batch = [pad_tensor(x, pad=src_max_len, dim=dim) for x in batch]

    # stack all
    xs = torch.stack(batch, dim=0)
    return xs.long(), sequence_lengths.int()

class TestDataset(data.Dataset):
    def __init__(self,  ko_path, ko_word2id):
        self.load_data(ko_path)
        self.ko_word2id = ko_word2id
        
        
    def load_data(self, ko_path):
        korean_test_data_ = pd.read_csv("./korean_data/test_korean.csv")
        korean_test_data =korean_test_data_['Korean'].iloc[:2000].values
        korean_test_data_token = []
        for sent in korean_test_data:
            korean_test_data_token.append([token for token in nltk.tokenize.word_tokenize(sent)])
        korean_test_data_token = [' '.join(token) for token in korean_test_data_token]
        self.ko_seqs = korean_test_data_token
        
    def __len__(self):
        return len(self.ko_seqs)

    def __getitem__(self, index):
        ko_seqs = self.ko_seqs[index]
        ko_seqs = self.process(ko_seqs, self.ko_word2id)
        return ko_seqs       

    def process(self, seq, word2id):
        sequence = []
        sequence.append(word2id["<s>"])
        words = seq.strip().split(' ')
        for word in words:
            if word in word2id:
                sequence.append(word2id[word]) # 
            else:
                sequence.append(3) # replace by <unk> token
        sequence.append(word2id["</s>"])
        sequence = torch.Tensor(sequence)
        return sequence
    
    
def test(model):
    
    with open("./korean_word2id.pkl", "rb") as f:
        korean_word2id = pickle.load(f)
    
    test_dataset = TestDataset('./test_korean.pkl', korean_word2id)
    test_loader = data.DataLoader(test_dataset, batch_size=model_config.batch_size, shuffle=False, collate_fn=test_pad_collate, drop_last=False)
    model.eval()
    j = 0
    
    f = open('prediction_result.txt', 'w')
    for idx, batch in enumerate(test_loader):
        x, x_len= batch
        x = x.cuda()
        pred = model.greedy_decoding(x)

        for i in range(pred.shape[0]):
            j+=1
            
            pred_indices = pred[i].data.cpu().tolist()
            input_indices = x[i].data.cpu().tolist()

            if 2 in pred_indices:
                pred_len = pred_indices.index(2)
            else:
                pred_len = 128

            if 2 in input_indices:
                input_len = input_indices.index(2)
            else:
                input_len = 128

            pred_words = [english_id2word[idx] for i,idx in enumerate(pred_indices) if i <= pred_len]
            input_words = [korean_id2word[idx] for i,idx in enumerate(input_indices) if i <= input_len]
            
            if j%50 == 0 :
                print('========== index {} ========='.format(j))
                print('입력:{}'.format(' '.join(input_words[1:-1])))
                print('출력:{}'.format(' '.join(pred_words[:-1])))

            f.write(' '.join(pred_words[:-1]))
            f.write('\n')

# %%
test(model)
# Out:
# ========== index 50 =========
# 입력:나이가 들어도 <unk> 맨날 싸우는 것 같아 .
# 출력:I have to know how I have to get to get to the way to the way .
# ========== index 100 =========
# 입력:너는 무섭거나 어려워하는 때가 언젠데 ?
# 출력:I know if you know the time , I know you know ?
# ========== index 150 =========
# 입력:내가 영어 잘 못 하니까 네가 한국어 공부해야 해 .
# 출력:I have to know how I have to study English .
# ========== index 200 =========
# 입력:두 번째로 좋아하는 음악은 <unk> .
# 출력:Second , I have to know the music .
# ========== index 250 =========
# 입력:주제 : 여러분이 세상을 <unk> 믿는 한 명의 한국인을 생각해 보세요 .
# 출력:To be aware of the world , you are going to see the world .
# ========== index 300 =========
# 입력:<unk> 작품은 <unk> 나타나면서 한국의 <unk> 주체적으로 표현한 <unk> 평가해요 .
# 출력:I have to know the Korean traditional store and the place to be able to be able to be able to know the right now .
# ========== index 350 =========
# 입력:내 친구는 호주에 있어서 너무 보고 싶어 .
# 출력:I have to know my friend before I have been now .
# ========== index 400 =========
# 입력:<unk> <unk> 삼각형 모양을 매우 잘 <unk> 할 수 있습니다 .
# 출력:I have to know the shape of the shape of the shape of the shape of the shape .
# ========== index 450 =========
# 입력:그중에서도 연어 초밥과 참치 초밥을 가장 좋아합니다 .
# 출력:I have to know the most popular food .
# ========== index 500 =========
# 입력:나는 정말 <unk> 갖고 싶어요 .
# 출력:I have to know how I have to know .
# ========== index 550 =========
# 입력:너는 대학교에서 어떤 걸 <unk> ?
# 출력:What is you know what I have to go to college ?
# ========== index 600 =========
# 입력:나는 거의 목이 졸려 죽을 뻔했어요 .
# 출력:I have been to go to the old age .
# ========== index 650 =========
# 입력:당신은 혼자가 아니란 것을 잊지 말아요 .
# 출력:I know you know what you are working .
# ========== index 700 =========
# 입력:오래된 <unk> 맛은 좋아요 .
# 출력:I have to know the old taste of the old .
# ========== index 750 =========
# 입력:도대체 여기서 누가 범인인 거야 ?
# 출력:I know that I have to know here ?
# ========== index 800 =========
# 입력:당신이 심심하지 않으려면 같이 사는 것이 좋습니다 .
# 출력:I know you have to know if you are working with the future .
# ========== index 850 =========
# 입력:첫 교육 이전에 트레이너가 고객에게 요구해야 할 양식은 무엇인가요 ?
# 출력:What is the first time of the first time to be the company ?
# ========== index 900 =========
# 입력:이것은 샤워 시 <unk> 각질 제거에 도움이 됩니다 .
# 출력:If you have to get a massage , you need to make a free rest .
# ========== index 950 =========
# 입력:나는 화장실을 매일 밤 청소해요 .
# 출력:I have to know the bathroom every night .
# ========== index 1000 =========
# 입력:한반도의 고유 생물 , 야생 생물들을 만나볼 수 있습니다 .
# 출력:The Korean food is the most popular of the world .
# ========== index 1050 =========
# 입력:너는 나를 며칠 전부터 먹고 싶었어 ?
# 출력:I know you have to go to the time before ?
# ========== index 1100 =========
# 입력:노력이 필요한 것은 크게 다르지 않다고 생각합니다 .
# 출력:I know what we need to know what we need to know .
# ========== index 1150 =========
# 입력:영상이 <unk> <unk> 유튜브 채널 구독하기 !
# 출력:I have to know the video of the video , and I have been going to receive the computer .
# ========== index 1200 =========
# 입력:불필요한 <unk> 줄여서 재포장을 해주실수 있나요 ?
# 출력:When can you know the way to the way to the way ?
# ========== index 1250 =========
# 입력:인터넷 뱅킹을 하다가 어려워서 포기했어요 .
# 출력:I have been to know the Internet before I have been able to get to get a computer .
# ========== index 1300 =========
# 입력:이 가게에는 제 마음에 드는 것이 딱히 없네요 .
# 출력:I have to know this store , but I have to know .
# ========== index 1350 =========
# 입력:그럼 답변 받으시는 대로 , 어떻게 되는지 업데이트 해주세요 .
# 출력:If you know , I know the schedule , I have to know the time .
# ========== index 1400 =========
# 입력:요리하다 갑자기 <unk> 물어봤어요 .
# 출력:I have to know the time ago , but I have to know the time .
# ========== index 1450 =========
# 입력:국가에 따라 배송비가 상이하니 구매 전에 꼭 확인해주세요 .
# 출력:I have to know the price of the price of the price of the price of the price .
# ========== index 1500 =========
# 입력:전 원래 길을 잘 찾아다니는 <unk> .
# 출력:I have been to know the road of the road .
# ========== index 1550 =========
# 입력:네오디뮴 자석을 통해 본 제품은 자기가 <unk> , 즉 인체에 가장 좋은 가우스 , <unk> <unk> 고 효 <unk> 설정했습니다 .
# 출력:The product is the best to be a good amount of the product and the best to be made .
# ========== index 1600 =========
# 입력:문제가 있다면 당신은 어떻게 해결할 건가요 ?
# 출력:What is you know if you need to solve ?
# ========== index 1650 =========
# 입력:또다시 그러면 한 시간 동안 수영장 밖에 나와 있는 거다 .
# 출력:Then I have to go to the restaurant again .
# ========== index 1700 =========
# 입력:거기에는 미국 드라마에 대한 내용 들이 나와 있었어 .
# 출력:I know the United States , I have been to the United States .
# ========== index 1750 =========
# 입력:나는 시스템을 만든 경험이 있습니다 .
# 출력:I have to know the data of the price .
# ========== index 1800 =========
# 입력:제가 날씨 일정을 봤을 때부터 비가 내리고 있었습니다 .
# 출력:I have been to go to the weather because I have been late .
# ========== index 1850 =========
# 입력:<unk> <unk> <unk> 느껴져서 <unk> 호감이 갑니다 .
# 출력:I have to know the reservation , but I have to get a reservation for a meal .
# ========== index 1900 =========
# 입력:2015년에도 변하지 말고 쭉 사랑하자 .
# 출력:I know that I have to know how much I have to know .
# ========== index 1950 =========
# 입력:이 아이가 당신의 어린 <unk> ?
# 출력:I know the child , I have been to the child ?
# ========== index 2000 =========
# 입력:그 <unk> 족구와 축구가 포함됩니다 .
# 출력:I have to know the same time ago .

# %%
# 과제

1. query, key, value 간의 관계에 대해 작성해주세요.
- query: 현재 처리하고자 하는 token을 나타내는 vector 
  key: label. sequence 내에 있는 모든 token에 대한 id 
  value: key와 연결된 실제 token을 나타내는 vector 
  즉, key가 폴더, value가 key라는 폴더에 위치한 data, query가 찾고자하는 값이라고 볼 수 있다. 

2. multi-head 의 필요성에 대해 작성해주세요.
- 한번의 attention을 하는 것보다 병렬로 여러 번 사용하는 게 더 효과적이다. 
  다른 시각에서 정보를 수집하는 역할을 한다. 

3. BERT 사전 학습의 두가지 태스크에 대해 설명해주세요.
- MLM: 양방향성으로 언어 모델 학습 
  NSP: 입력값에 다음 문장도 함께 추가하여 다음 문장인지 여부를 분류(Binary Classification)

4. Transformer embedding과 BERT embedding의 차이점 두가지를 작성해주세요.
- Transformer embedding: positional encoding을 통해 위치 정보를 포함한다. 
                        sin 함수를 사용 neural network가 상대적 위치를 학습할 수 있게 한다. 
  BERT embedding: positional encoding 대신 positional embedding을 사용하고, 추가로 segment embedding을 사용한다. 
                  segment embedding을 사용해 앞뒤 문장을 연결할 수 있다.
